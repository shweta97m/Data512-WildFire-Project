# %% [markdown]
# # Part 1 - Common Analysis | Wildfire Data Pull

# %% [markdown]
# Common Analysis is the first step of our borader project that focuses on the impact of the wildfires in US. In this common analysis, we are going into the first analyze in detail the fires of our alloted city and come up with an estimate. This is a rough estimate the wildfire impacts on the city which might have a more profound negative effect on  health, tourism, property, and other aspects of society.

# %% [markdown]
# # Step 0 - Data Acquistion

# %% [markdown]
# ## Data Description
#
# Assigned City - Bismarck, North Dakota [46.825905, -100.778275.]
#
# Objective - Analyze wildfire impacts on the city assigned
#
# In this step we aquire the data that contains the information of all the wildfires from 1800s to the present. [(Combined wildland fire datasets for the United States and certain territories, 1800s-Present (combined wildland fire polygons)](https://www.sciencebase.gov/catalog/item/61aa537dd34eb622f699df81) The initial task is to ingest this data and get the data relevant to the assigned city (Bismarck)
#
# The data resides in a GeoJSON zip file (“Wildland Fire Polygons Fire Feature Data Open Source GeoJSON Files”). The file that contains the data of interest is in [USGS_Wildland_Fire_Combined_Dataset.json](https://drive.google.com/file/d/14BO0R0uLR8kYZ_r7529Pa61C2-qJd0dx/view?usp=drive_link).

# %% [markdown]
# ## Data Ingestion
#
# For data ingestion I will be referring to the code sample provided [here](https://drive.google.com/file/d/1RFVyIQ5bfrGZH72V8ItnRrnFiTaHYb3e/view?usp=drive_link). This contains the code that illustrate how to perform some basic geodetic computations related to the Wildfire course project. The notebook is structure as a set of examples that illustrate something about the structure of the data or illustrate a way to compute specific values. This notebook is not a tutorial on performing geodetic computations, but illustrates a number of key concepts. This notebook should provide enough information to complete the Wildfire assignment. The complete [Wildfire dataset](https://www.sciencebase.gov/catalog/item/61aa537dd34eb622f699df81) can be retrieved from a US government repository. I have noticed that the repository is sometimes "down" and does not respond. It probably makes sense to get the dataset as soon as possible.
#
# This notebook has dependencies on [Pyproj](https://pyproj4.github.io/pyproj/stable/index.html), the [geojson](https://pypi.org/project/geojson/) module and on the wildfire user module. Pyproj and geojson can be installed via pip. The wildfire user module should be downloaded from the course website, unzipped, and moved into the folder pointed to by your PYTHONPATH system variable.
#
# ### License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 13, 2023

# %% [markdown]
# ## Setup
#
# We first set the working dependencies and constants that are required to process the GeoJSON. Sample code has been obtained from [this notebook](https://drive.google.com/file/d/1RFVyIQ5bfrGZH72V8ItnRrnFiTaHYb3e/view)
#
# The setup contains the following steps
# 1. Import all relevant packages
# 2. Define all the relevant constants that will be used throughout the script.
# 3. Reading the GeoJSON Reader module from the [sample code](https://drive.google.com/drive/folders/1MskdQFkAoYK414BkRJjCGvGw0MQd-P_6?usp=drive_link)

# %%
# pip install geojson

# %%
# Import the sys module, which provides access to variables used or maintained by the Python interpreter
import sys

# Insert a directory path to the system path, allowing Python to search for modules in that directory
sys.path.insert(1, '../dependencies/wildfire/wildfire')

# Import the pandas library and alias it as pd
import pandas as pd

# Import the numpy library and alias it as np
import numpy as np

# Import the json module, which provides methods for working with JSON data
import json

# Import the geodesic function from the geopy.distance module
from geopy.distance import geodesic

# Import the Transformer and Geod classes from the pyproj module
from pyproj import Transformer, Geod

# Import the Reader class from the Reader module and alias it as WFReader
from Reader import Reader as WFReader

# There is a GeoJSON reader that you might try if you wanted to read the data. It has its own quirks.
# There will be an example below that reads the sample file "Wildfire_short_sample.json"

import geojson
import time

# %%
# Out:
# 'C:\\Users\\shwet\\Downloads\\GeoJSON Files\\GeoJSON Exports\\USGS_Wildland_Fire_Combined_Dataset.json'

# %%
SAMPLE_DATA_FILENAME = r"C:\Users\shwet\Downloads\Data512 - ProjectPart1_CommonAnalysis_ShwetaManjunath\dependencies\wildfire\wildfire\Wildfire_short_sample.json"

# print out where we think we're going to find the sample data
print(f"{SAMPLE_DATA_FILENAME=}")
# Out:
# SAMPLE_DATA_FILENAME='C:\\Users\\shwet\\Downloads\\Data512 - ProjectPart1_CommonAnalysis_ShwetaManjunath\\dependencies\\wildfire\\wildfire\\Wildfire_short_sample.json'

# %%
# The 'Wildfire_short_sample.json' is an extraction from the full 'USGS_Wildland_Fire_Combined_Dataset.json'
# dataset extracting some of the major wildfires in California. These were extracted by name, with possible names
# coming from https://en.wikipedia.org/wiki/List_of_California_wildfires

# The sample file includes data for 13 fires, mostly oriented around the uniqueness of the name. Naming conventions
# for wildfires is really adhoc, which makes finding any named fire in the dataset a disambiguation mess. The point
# of the sample is to provide something small to test with before committing to processing the much larger full dataset.

# data file that contains the GeoJSON 
EXTRACT_FILENAME = r"C:\Users\shwet\Downloads\GeoJSON Files\GeoJSON Exports\USGS_Wildland_Fire_Combined_Dataset.json"
EXTRACT_FILENAME
# Out:
# 'C:\\Users\\shwet\\Downloads\\GeoJSON Files\\GeoJSON Exports\\USGS_Wildland_Fire_Combined_Dataset.json'

# %%
# A dictionary of some city locations from the US west coast states.
CITY_DATA = {
    'bismarck' :     {'city'   : 'bismarck', 
                    'latlon' : [46.825905, -100.778275]}}

# %% [markdown]
# You have a number of different options for working with the wildfire data. Python has GeoJSON readers and ArcGIS file readers as distribution modules you can install. If you are a pandas pro, it supposedly has GeoJSON and ArcGIS data readers.

# %% [markdown]
# # Step 1 - Load the GeoJSON Data

# %% [markdown]
# This information is primarily used to obtain the fire estimate. The common research question that you are to answer is:
# What are the estimated smoke impacts on your assigned city for the last 60 years?
# We have to create an annual estimate of wildfire smoke in our assigned city. This estimate is just a number that we can eventually use to build a predictive model. Technically, smoke impact should probably be considered the health, tourism, economic or other social problems that result from the smoke. For this we'll generically call your estimate the wildfire smoke impact. We will consider other potential social and economic impacts during Part 2 of the course project. For now, we need some kind of number to represent an estimate of the smoke our city saw during each annual fire season.

# %% [markdown]
# Why is this an estimate of fire smoke? These are estimates because of a number of problems that are not easy to resolve and simplifications to make this course project reasonable for just a few weeks of work. One example is that actual smoke impact is based on wind direction over a course of several days, the intensity of the fire, and its duration. However, the fire polygon data only gives a year for each fire - it does not provide specific start and end dates for the fire

# %% [markdown]
# Your smoke estimate should adhere to the following conditions:
# 1. The estimate only considers the last 60 years of wildland fires (1963-2023).
# 2. The estimate only considers fires that are within 1250 miles of your assigned city.
# 3. An annual fire season will run from May 1st through October 31st.

# %% [markdown]
# ## Load the wildfire data using the geojson module

# %% [markdown]
# In this example we use the GeoJSON module ([documentation](https://pypi.org/project/geojson/), [GitHub repo](https://github.com/jazzband/geojson)) to load the sample file. This module works mostly the way you would expect. GeoJSON is mostly just JSON, so actually, you don't even really need to use the GeoJSON module. However, that module will do some conversion of Geo type things to something useful. However, this example, and the examples that follow, do not rely on specific Geo features from geojson.

# %%
# Open a file, load it with the geojson loader

print(f"Attempting to open '{SAMPLE_DATA_FILENAME}'")
geojson_file = open(SAMPLE_DATA_FILENAME,"r")
print(f"Using GeoJSON module to load sample file '{SAMPLE_DATA_FILENAME}'")
gj_data = geojson.load(geojson_file)
geojson_file.close()
# Out:
# Attempting to open 'C:\Users\shwet\Downloads\Data512 - ProjectPart1_CommonAnalysis_ShwetaManjunath\dependencies\wildfire\wildfire\Wildfire_short_sample.json'
# Using GeoJSON module to load sample file 'C:\Users\shwet\Downloads\Data512 - ProjectPart1_CommonAnalysis_ShwetaManjunath\dependencies\wildfire\wildfire\Wildfire_short_sample.json'

# %%
# Print the keys from the object

gj_keys = list(gj_data.keys())
print("The loaded JSON dictionary has the following keys:")
print(gj_keys)
print()

# For all GeoJSON type things, the most important part of the file are the 'features'. 
# In the case of the wildfire dataset, each feature is a polygon (ring) of points that define the bounary of a fire

count = 0
for feature in gj_data['features']:
    count += 1
    #print(json.dumps(feature,indent=4))
    time.sleep(0.5)   # this slows the output to fix output rate limits for Jupyter

print(f"Found {count} features in the variable 'gj_data' ")
# Out:
# The loaded JSON dictionary has the following keys:
# ['displayFieldName', 'fieldAliases', 'geometryType', 'spatialReference', 'fields', 'features']
#
# Found 13 features in the variable 'gj_data'

# %%
# Get the first item in the list of features

SLOT = 0
gj_feature = gj_data['features'][SLOT]

# Print everyting in this dictionary (i.e., gj_feature) - it's long

print(f"The wildfire feature from slot '{SLOT}' of the loaded gj_data['features']")
print(json.dumps(gj_feature, indent=4))
# Out:
# The wildfire feature from slot '0' of the loaded gj_data['features']
# {
#     "attributes": {
#         "OBJECTID": 4956,
#         "USGS_Assigned_ID": 4956,
#         "Assigned_Fire_Type": "Wildfire",
#         "Fire_Year": 1932,
#         "Fire_Polygon_Tier": 1,
#         "Fire_Attribute_Tiers": "1 (1), 3 (3)",
#         "GIS_Acres": 219999.23754748085,
#         "GIS_Hectares": 89030.53273921262,
#         "Source_Datasets": "Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_State_California_Wildfire_Polygons (1)",
#         "Listed_Fire_Types": "Wildfire (3), Likely Wildfire (1)",
#         "Listed_Fire_Names": "MATILIJA (4)",
#         "Listed_Fire_Codes": "No code provided (4)",
#         "Listed_Fire_IDs": "0 (3)",
#         "Listed_Fire_IRWIN_IDs": "",
#         "Listed_Fire_Dates": "Listed Wildfire Discovery Date(s): 1932-09-07 (2) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1), 1932-09-07 - DATE_CUR field (1)",
#         "Listed_Fire_Causes": "9 - Miscellaneous (1)",
#         "Listed_Fire_Cause_Class": "Undetermined (3), Human (1)",
#         "Listed_Rx_Reported_Acres": null,
#         "Listed_Map_Digitize_Methods": "",
#         "Listed_Notes": "",
#         "Processing_Notes": "",
#         "Wildfire_Notice": "Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.",
#         "Prescribed_Burn_Notice": "Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.",
#         "Wildfire_and_Rx_Flag": null,
#         "Overlap_Within_1_or_2_Flag": null,
#         "Circleness_Scale": 0.3264782366249864,
#         "Circle_Flag": null,
#         "Exclude_From_Summary_Rasters": "No",
#         "Shape_Length": 185117.42477003767,
#         "Shape_Area": 890305327.3921262
#     },
#     "geometry": {
#         "rings": [
#             [
#                 [
#                     -2007910.3699999992,
#                     -382654.3025000002
#                 ],
#                 [
#                     -2007886.8686999995,
#                     -382794.5167999994
#                 ],
#                 [
#                     -2007839.7774,
#                     -382860.65750000067
#                 ],
#                 [
#                     -2007747.0418999996,
#                     -382878.7469999995
#                 ],
#                 [
#                     -2007637.0754000004,
#                     -382890.1484999992
#                 ],
#                 [
#                     -2007509.4678000007,
#                     -382919.8149999995
#                 ],
#                 [
#                     -2007230.8179000001,
#                     -382918.86140000075
#                 ],
#                 [
#                     -2006997.5754000004,
#                     -382938.2013000008
#                 ],
#                 [
#                     -2006678.3796999995,
#                     -382991.3883999996
#                 ],
#                 [
#                     -2006383.3211000003,
#                     -383080.7380999997
#                 ],
#                 [
#                     -2006185.9959999993,
#                     -383133.31540000066
#                 ],
#                 [
#                     -2006056.0844999999,
#                     -383153.0189999994
#                 ],
#                 [
#                     -2005936.3957000002,
#                     -383149.6168000009
#                 ],
#                 [
#                     -2005788.2020999994,
#                     -383104.56240000017
#                 ],
#                 [
#                     -2005759.7040999997,
#                     -382969.5127000008
#                 ],
#                 [
#                     -2005755.6585000008,
#                     -382818.49709999934
#                 ],
#                 [
#                     -2005748.1323000006,
#                     -382599.1616999991
#                 ],
#                 [
#                     -2005642.6709000003,
#                     -382402.57660000026
#                 ],
#                 [
#                     -2005445.3391999993,
#                     -382241.15389999934
#                 ],
#                 [
#                     -2005238.8057000004,
#                     -382147.3643999994
#                 ],
#                 [
#                     -2005108.8168000001,
#                     -382153.3060999997
#                 ],
#                 [
#                     -2004884.1992000006,
#                     -382236.2960999999
#                 ],
#                 [
#                     -2004637.9305000007,
#                     -382400.5293000005
#                 ],
#                 [
#                     -2004294.2146000005,
#                     -382549.3323999997
#                 ],
#                 [
#                     -2003946.138699999,
#                     -382719.6355000008
#                 ],
#                 [
#                     -2003683.2166000009,
#                     -382946.4322999995
#                 ],
#                 [
#                     -2003473.7788999993,
#                     -383174.46350000054
#                 ],
#                 [
#                     -2003284.7511,
#                     -383342.6054999996
#                 ],
#                 [
#                     -2003027.9536000006,
#                     -383595.5524000004
#                 ],
#                 [
#                     -2002884.193,
#                     -383756.7580999993
#                 ],
#                 [
#                     -2002573.8531,
#                     -383901.08919999935
#                 ],
#                 [
#                     -2002280.9246999994,
#                     -384093.31570000015
#                 ],
#                 [
#                     -2001930.6833999995,
#                     -384374.7726000007
#                 ],
#                 [
#                     -2001653.2223000005,
#                     -384646.3831999991
#                 ],
#                 [
#                     -2001304.6051000003,
#                     -384948.2324999999
#                 ],
#                 [
#                     -2001039.6743,
#                     -385206.52940000035
#                 ],
#                 [
#                     -2000653.5270000007,
#                     -385561.88269999996
#                 ],
#                 [
#                     -2000486.7490999997,
#                     -385672.38040000014
#                 ],
#                 [
#                     -2000436.8249999993,
#                     -385705.4603000004
#                 ],
#                 [
#                     -2000164.3216999993,
#                     -385851.2587000001
#                 ],
#                 [
#                     -1999989.6903000008,
#                     -385976.1453000009
#                 ],
#                 [
#                     -1999907.0427,
#                     -386035.2603999991
#                 ],
#                 [
#                     -1999715.1412000004,
#                     -386218.04810000025
#                 ],
#                 [
#                     -1999599.7941999994,
#                     -386300.05849999934
#                 ],
#                 [
#                     -1999479.1380000003,
#                     -386372.7006999999
#                 ],
#                 [
#                     -1999376.1298999991,
#                     -386413.8668000009
#                 ],
#                 [
#                     -1999288.241800001,
#                     -386416.29399999976
#                 ],
#                 [
#                     -1999258.0256999992,
#                     -386417.1355000008
#                 ],
#                 [
#                     -1999112.110200001,
#                     -386381.8482000008
#                 ],
#                 [
#                     -1999036.1954999994,
#                     -386257.9835999999
#                 ],
#                 [
#                     -1999020.2397000007,
#                     -386231.81829999946
#                 ],
#                 [
#                     -1998934.7007,
#                     -386091.5452999994
#                 ],
#                 [
#                     -1998897.6489000004,
#                     -385999.99340000004
#                 ],
#                 [
#                     -1998805.398600001,
#                     -385779.4138999991
#                 ],
#                 [
#                     -1998653.0528999995,
#                     -385569.5778999999
#                 ],
#                 [
#                     -1998548.0596999992,
#                     -385428.2207999993
#                 ],
#                 [
#                     -1998359.7133000009,
#                     -385385.4146999996
#                 ],
#                 [
#                     -1998199.9419,
#                     -385384.5145999994
#                 ],
#                 [
#                     -1997986.9109000005,
#                     -385423.3813000005
#                 ],
#                 [
#                     -1997838.197899999,
#                     -385509.8741999995
#                 ],
#                 [
#                     -1997792.4141000006,
#                     -385661.8336999994
#                 ],
#                 [
#                     -1997782.5089999996,
#                     -385833.54360000044
#                 ],
#                 [
#                     -1997801.360200001,
#                     -385980.98790000007
#                 ],
#                 [
#                     -1997792.7942999993,
#                     -386131.6133999992
#                 ],
#                 [
#                     -1997817.9444999993,
#                     -386225.8099000007
#                 ],
#                 [
#                     -1997826.7894000001,
#                     -386317.2138
#                 ],
#                 [
#                     -1997867.5646000002,
#                     -386411.19219999947
#                 ],
#                 [
#                     -1997928.7301000003,
#                     -386552.3772
#                 ],
#                 [
#                     -1997929.1265999991,
#                     -386553.15550000034
#                 ],
#                 [
#                     -1998004.117900001,
#                     -386700.91029999964
#                 ],
#                 [
#                     -1998004.7749000005,
#                     -386701.78360000066
#                 ],
#                 [
#                     -1998103.8946000002,
#                     -386833.18700000085
#                 ],
#                 [
#                     -1998103.9503000006,
#                     -386833.29140000045
#                 ],
#                 [
#                     -1998212.1433000006,
#                     -387015.1004000008
#                 ],
#                 [
#                     -1998275.8600999992,
#                     -387300.9526000004
#                 ],
#                 [
#                     -1998286.1456000004,
#                     -387385.65970000066
#                 ],
#                 [
#                     -1998299.5402000006,
#                     -387495.8869000003
#                 ],
#                 [
#                     -1998190.3226999994,
#                     -387711.1618000008
#                 ],
#                 [
#                     -1998009.6391000003,
#                     -387808.06819999963
#                 ],
#                 [
#                     -1997775.8926999997,
#                     -387852.09050000086
#                 ],
#                 [
#                     -1997521.2065999992,
#                     -387886.79030000046
#                 ],
#                 [
#                     -1997278.3319000006,
#                     -387905.06379999965
#                 ],
#                 [
#                     -1996927.4023000002,
#                     -387876.07850000076
#                 ],
#                 [
#                     -1996757.7446999997,
#                     -387953.25009999983
#                 ],
#                 [
#                     -1996564.8144000005,
#                     -387997.82579999976
#                 ],
#                 [
#                     -1996384.6684000008,
#                     -387949.97250000015
#                 ],
#                 [
#                     -1996121.1254999992,
#                     -387986.9116999991
#                 ],
#                 [
#                     -1995847.1063,
#                     -388019.1978999991
#                 ],
#                 [
#                     -1995625.8402999993,
#                     -388049.65059999935
#                 ],
#                 [
#                     -1995467.269200001,
#                     -388107.3225999996
#                 ],
#                 [
#                     -1995299.0653000008,
#                     -388177.4293000009
#                 ],
#                 [
#                     -1995111.0277999993,
#                     -388283.0207000002
#                 ],
#                 [
#                     -1994947.6064999998,
#                     -388400.3312999997
#                 ],
#                 [
#                     -1994786.8904999997,
#                     -388582.65809999965
#                 ],
#                 [
#                     -1994684.2532000002,
#                     -388785.93989999965
#                 ],
#                 [
#                     -1994557.322899999,
#                     -389019.2497000005
#                 ],
#                 [
#                     -1994361.8554999996,
#                     -389334.01549999975
#                 ],
#                 [
#                     -1994272.4387999997,
#                     -389513.5627999995
#                 ],
#                 [
#                     -1994081.4247999992,
#                     -389726.9444999993
#                 ],
#                 [
#                     -1993886.2265000008,
#                     -389868.96160000004
#                 ],
#                 [
#                     -1993650.6594999991,
#                     -390068.24530000053
#                 ],
#                 [
#                     -1993593.6740000006,
#                     -390116.4474999998
#                 ],
#                 [
#                     -1993383.6198999994,
#                     -390261.7918999996
#                 ],
#                 [
#                     -1992995.3709999993,
#                     -390338.4604000002
#                 ],
#                 [
#                     -1992979.9048999995,
#                     -390341.5145999994
#                 ],
#                 [
#                     -1992707.1390000004,
#                     -390446.1062000003
#                 ],
#                 [
#                     -1992362.3287000004,
#                     -390443.25210000016
#                 ],
#                 [
#                     -1992056.2865999993,
#                     -390458.99530000053
#                 ],
#                 [
#                     -1991771.4462000001,
#                     -390431.6548999995
#                 ],
#                 [
#                     -1991490.204500001,
#                     -390379.45639999956
#                 ],
#                 [
#                     -1991322.7502999995,
#                     -390342.5918000005
#                 ],
#                 [
#                     -1991321.9806999993,
#                     -390342.4219000004
#                 ],
#                 [
#                     -1991176.6778999995,
#                     -390282.9726
#                 ],
#                 [
#                     -1990918.3180999998,
#                     -390208.1313000005
#                 ],
#                 [
#                     -1990369.3570000008,
#                     -390242.15440000035
#                 ],
#                 [
#                     -1990079.2522999998,
#                     -390419.7332000006
#                 ],
#                 [
#                     -1989752.8994999994,
#                     -390723.3989000004
#                 ],
#                 [
#                     -1989393.0162000004,
#                     -391017.5684999991
#                 ],
#                 [
#                     -1989169.0726999994,
#                     -391197.06149999984
#                 ],
#                 [
#                     -1988945.8412999995,
#                     -391366.4180999994
#                 ],
#                 [
#                     -1988781.6440999992,
#                     -391480.4090999998
#                 ],
#                 [
#                     -1988478.5176999997,
#                     -391709.5184000004
#                 ],
#                 [
#                     -1988348.9754000008,
#                     -391784.4466999993
#                 ],
#                 [
#                     -1988092.8894999996,
#                     -391933.64389999956
#                 ],
#                 [
#                     -1987986.5233999994,
#                     -392027.3763999995
#                 ],
#                 [
#                     -1987633.6675000004,
#                     -392043.6425000001
#                 ],
#                 [
#                     -1987444.0252999999,
#                     -392021.9411999993
#                 ],
#                 [
#                     -1987211.0682999995,
#                     -391868.49310000055
#                 ],
#                 [
#                     -1986955.3275000006,
#                     -391738.0248000007
#                 ],
#                 [
#                     -1986823.1257000007,
#                     -391747.97030000016
#                 ],
#                 [
#                     -1986683.0289999992,
#                     -391804.47360000014
#                 ],
#                 [
#                     -1986591.0269000009,
#                     -391932.7923000008
#                 ],
#                 [
#                     -1986508.3619,
#                     -392128.10199999996
#                 ],
#                 [
#                     -1986287.5905000009,
#                     -392334.69710000046
#                 ],
#                 [
#                     -1986167.8990000002,
#                     -392438.4553999994
#                 ],
#                 [
#                     -1986016.2846000008,
#                     -392539.40410000086
#                 ],
#                 [
#                     -1985753.5607999992,
#                     -392593.1973000001
#                 ],
#                 [
#                     -1985560.6698000003,
#                     -392638.0554000009
#                 ],
#                 [
#                     -1985426.1314000003,
#                     -392745.1405999996
#                 ],
#                 [
#                     -1985380.1917000003,
#                     -392869.87519999966
#                 ],
#                 [
#                     -1985373.4177,
#                     -393081.90589999966
#                 ],
#                 [
#                     -1985371.7810999993,
#                     -393275.81409999914
#                 ],
#                 [
#                     -1985354.2346,
#                     -393428.41559999995
#                 ],
#                 [
#                     -1985243.8895999994,
#                     -393706.0733000003
#                 ],
#                 [
#                     -1985129.0078999996,
#                     -393964.21660000086
#                 ],
#                 [
#                     -1984933.4162000008,
#                     -394171.6150000002
#                 ],
#                 [
#                     -1984787.7281999998,
#                     -394271.22030000016
#                 ],
#                 [
#                     -1984353.1304000001,
#                     -394513.37289999984
#                 ],
#                 [
#                     -1984010.3500999995,
#                     -394706.83589999937
#                 ],
#                 [
#                     -1983655.5494,
#                     -394875.45529999956
#                 ],
#                 [
#                     -1983390.898,
#                     -394974.7785
#                 ],
#                 [
#                     -1983199.7545999996,
#                     -395053.80780000053
#                 ],
#                 [
#                     -1982968.3084999993,
#                     -395228.2361999992
#                 ],
#                 [
#                     -1982712.4332999997,
#                     -395525.8326999992
#                 ],
#                 [
#                     -1982574.2672000006,
#                     -395644.25659999996
#                 ],
#                 [
#                     -1982452.1565000005,
#                     -395831.43989999965
#                 ],
#                 [
#                     -1982347.6702999994,
#                     -395986.83210000023
#                 ],
#                 [
#                     -1982220.0143,
#                     -396123.4450000003
#                 ],
#                 [
#                     -1982110.5776000004,
#                     -396204.11390000023
#                 ],
#                 [
#                     -1982002.091,
#                     -396208.48230000027
#                 ],
#                 [
#                     -1981870.2146000005,
#                     -396152.77710000053
#                 ],
#                 [
#                     -1981771.659,
#                     -395971.9397999998
#                 ],
#                 [
#                     -1981752.3413999993,
#                     -395755.23790000007
#                 ],
#                 [
#                     -1981713.9871999994,
#                     -395456.9545000009
#                 ],
#                 [
#                     -1981670.3303999994,
#                     -395149.3540000003
#                 ],
#                 [
#                     -1981553.3135000002,
#                     -394768.8847000003
#                 ],
#                 [
#                     -1981426.3583000004,
#                     -394452.9763999991
#                 ],
#                 [
#                     -1981244.7676999997,
#                     -394305.04759999923
#                 ],
#                 [
#                     -1981099.4087000005,
#                     -394231.82740000077
#                 ],
#                 [
#                     -1980975.3562000003,
#                     -394236.4462000001
#                 ],
#                 [
#                     -1980899.2969000004,
#                     -394312.61810000055
#                 ],
#                 [
#                     -1980835.4765000008,
#                     -394441.37450000085
#                 ],
#                 [
#                     -1980833.3069000002,
#                     -394486.6732999999
#                 ],
#                 [
#                     -1980833.2414999995,
#                     -394488.0175999999
#                 ],
#                 [
#                     -1980825.7024000008,
#                     -394640.5895000007
#                 ],
#                 [
#                     -1980757.2877999991,
#                     -394856.74569999985
#                 ],
#                 [
#                     -1980716.7271999996,
#                     -395125.18090000004
#                 ],
#                 [
#                     -1980711.3259999994,
#                     -395437.0611000005
#                 ],
#                 [
#                     -1980711.4968999997,
#                     -395438.0295000002
#                 ],
#                 [
#                     -1980759.2214000002,
#                     -395709.1612999998
#                 ],
#                 [
#                     -1980759.466,
#                     -395710.03309999965
#                 ],
#                 [
#                     -1980834.6000999995,
#                     -395978.3356999997
#                 ],
#                 [
#                     -1980834.8716000002,
#                     -395979.27610000037
#                 ],
#                 [
#                     -1980917.5381000005,
#                     -396266.61539999954
#                 ],
#                 [
#                     -1980917.5382000003,
#                     -396266.69150000066
#                 ],
#                 [
#                     -1980925.448999999,
#                     -396447.8355999999
#                 ],
#                 [
#                     -1980887.382099999,
#                     -396646.6121999994
#                 ],
#                 [
#                     -1980799.8717,
#                     -396794.43909999914
#                 ],
#                 [
#                     -1980627.3582000006,
#                     -396886.2993999999
#                 ],
#                 [
#                     -1980412.7499000002,
#                     -396905.05509999953
#                 ],
#                 [
#                     -1980225.0417999998,
#                     -396895.0485999994
#                 ],
#                 [
#                     -1980073.7288000006,
#                     -396886.9036999997
#                 ],
#                 [
#                     -1979796.2566999998,
#                     -396837.4008000009
#                 ],
#                 [
#                     -1979425.1056999993,
#                     -396681.5560999997
#                 ],
#                 [
#                     -1979175.1872000005,
#                     -396642.8719999995
#                 ],
#                 [
#                     -1979052.5395,
#                     -396640.1568999998
#                 ],
#                 [
#                     -1978844.2617000006,
#                     -396605.6495999992
#                 ],
#                 [
#                     -1978660.6579999998,
#                     -396596.34050000086
#                 ],
#                 [
#                     -1978502.5274999999,
#                     -396615.9065000005
#                 ],
#                 [
#                     -1978179.8827999998,
#                     -396708.00689999945
#                 ],
#                 [
#                     -1978034.6984,
#                     -396782.90059999935
#                 ],
#                 [
#                     -1977723.4593000002,
#                     -396910.4936999995
#                 ],
#                 [
#                     -1977486.8716000002,
#                     -396982.47089999914
#                 ],
#                 [
#                     -1977362.0810000002,
#                     -397104.6405999996
#                 ],
#                 [
#                     -1977258.1151,
#                     -397222.1793000009
#                 ],
#                 [
#                     -1977060.9659000002,
#                     -397302.27710000053
#                 ],
#                 [
#                     -1976905.5592999998,
#                     -397400.58809999935
#                 ],
#                 [
#                     -1976768.5141000003,
#                     -397470.19129999913
#                 ],
#                 [
#                     -1976641.6009,
#                     -397489.4883999992
#                 ],
#                 [
#                     -1976511.0711000003,
#                     -397412.67310000025
#                 ],
#                 [
#                     -1976294.8213999998,
#                     -397303.8629999999
#                 ],
#                 [
#                     -1976071.8329000007,
#                     -397179.5088999998
#                 ],
#                 [
#                     -1975819.0870999992,
#                     -397048.0985000003
#                 ],
#                 [
#                     -1975558.6773000006,
#                     -397004.75579999946
#                 ],
#                 [
#                     -1975295.0344999991,
#                     -397027.9989
#                 ],
#                 [
#                     -1975195.637599999,
#                     -397057.8643999994
#                 ],
#                 [
#                     -1975099.9028999992,
#                     -397183.79649999924
#                 ],
#                 [
#                     -1975039.1579,
#                     -397325.64079999924
#                 ],
#                 [
#                     -1975003.4306000005,
#                     -397547.9473000001
#                 ],
#                 [
#                     -1975011.8540000003,
#                     -397811.9134999998
#                 ],
#                 [
#                     -1975031.3841999993,
#                     -398069.88049999997
#                 ],
#                 [
#                     -1975035.9661999997,
#                     -398196.7898999993
#                 ],
#                 [
#                     -1975014.8910000008,
#                     -398387.9877000004
#                 ],
#                 [
#                     -1974975.5950000007,
#                     -398514.48310000077
#                 ],
#                 [
#                     -1974922.0935999993,
#                     -398639.0265999995
#                 ],
#                 [
#                     -1974922.3791000005,
#                     -398639.56159999967
#                 ],
#                 [
#                     -1974991.3673,
#                     -398769.7804000005
#                 ],
#                 [
#                     -1975044.1478000004,
#                     -398996.0008000005
#                 ],
#                 [
#                     -1975044.1230999995,
#                     -398996.3987000007
#                 ],
#                 [
#                     -1975026.0074000005,
#                     -399293.7000999991
#                 ],
#                 [
#                     -1974990.7634999994,
#                     -399585.0105000008
#                 ],
#                 [
#                     -1974929.8995999992,
#                     -399820.2133000009
#                 ],
#                 [
#                     -1974821.6690999996,
#                     -400201.0445000008
#                 ],
#                 [
#                     -1974816.3455999997,
#                     -400239.0259000007
#                 ],
#                 [
#                     -1974767.670499999,
#                     -400586.3937999997
#                 ],
#                 [
#                     -1974714.6169000007,
#                     -400881.9528000001
#                 ],
#                 [
#                     -1974714.6541000009,
#                     -400882.85789999925
#                 ],
#                 [
#                     -1974724.5263,
#                     -401119.06829999946
#                 ],
#                 [
#                     -1974726.9090999998,
#                     -401176.0834999997
#                 ],
#                 [
#                     -1974726.9598999992,
#                     -401176.1687000003
#                 ],
#                 [
#                     -1974799.9473,
#                     -401328.08960000053
#                 ],
#                 [
#                     -1974932.1882000007,
#                     -401546.18930000067
#                 ],
#                 [
#                     -1975071.6199999992,
#                     -401728.1071000006
#                 ],
#                 [
#                     -1975384.8004,
#                     -401783.0722000003
#                 ],
#                 [
#                     -1975584.4192999993,
#                     -401740.1727000009
#                 ],
#                 [
#                     -1975786.7493999992,
#                     -401655.3507000003
#                 ],
#                 [
#                     -1975923.6162,
#                     -401557.9855000004
#                 ],
#                 [
#                     -1975924.3605000004,
#                     -401557.9439000003
#                 ],
#                 [
#                     -1976065.5347000007,
#                     -401549.3602000009
#                 ],
#                 [
#                     -1976179.4134999998,
#                     -401581.5769999996
#                 ],
#                 [
#                     -1976318.4869999997,
#                     -401601.09640000015
#                 ],
#                 [
#                     -1976500.6261999998,
#                     -401724.5865000002
#                 ],
#                 [
#                     -1976672.4154000003,
#                     -401857.43569999933
#                 ],
#                 [
#                     -1976794.9211999997,
#                     -401953.2690999992
#                 ],
#                 [
#                     -1977035.6384999994,
#                     -402166.99200000055
#                 ],
#                 [
#                     -1977129.5439,
#                     -402328.0700000003
#                 ],
#                 [
#                     -1977192.1067999993,
#                     -402462.19370000064
#                 ],
#                 [
#                     -1977259.7795000002,
#                     -402698.54089999944
#                 ],
#                 [
#                     -1977465.5319999997,
#                     -403137.61659999937
#                 ],
#                 [
#                     -1977588.9410999995,
#                     -403371.43280000053
#                 ],
#                 [
#                     -1977641.4816999994,
#                     -403569.85160000063
#                 ],
#                 [
#                     -1977641.5173000004,
#                     -403570.33210000023
#                 ],
#                 [
#                     -1977641.5288999993,
#                     -403570.6442000009
#                 ],
#                 [
#                     -1977657.7170000002,
#                     -403894.08779999986
#                 ],
#                 [
#                     -1977657.7972,
#                     -403894.3610999994
#                 ],
#                 [
#                     -1977748.2897999994,
#                     -404215.16640000045
#                 ],
#                 [
#                     -1977870.6011999995,
#                     -404404.15190000087
#                 ],
#                 [
#                     -1978045.2953999992,
#                     -404522.5471999999
#                 ],
#                 [
#                     -1978198.7906,
#                     -404590.38910000026
#                 ],
#                 [
#                     -1978513.1837000009,
#                     -404583.2759000007
#                 ],
#                 [
#                     -1978686.5874000005,
#                     -404508.47470000014
#                 ],
#                 [
#                     -1978846.9973000009,
#                     -404378.0387999993
#                 ],
#                 [
#                     -1978993.9517,
#                     -404230.0971000008
#                 ],
#                 [
#                     -1979154.2946000006,
#                     -404085.9187000003
#                 ],
#                 [
#                     -1979367.6293000001,
#                     -403873.95109999925
#                 ],
#                 [
#                     -1979555.3507000003,
#                     -403820.2416999992
#                 ],
#                 [
#                     -1979711.9899000004,
#                     -403794.2619000003
#                 ],
#                 [
#                     -1979913.1697000004,
#                     -403758.03810000047
#                 ],
#                 [
#                     -1980110.8341000006,
#                     -403760.3775999993
#                 ],
#                 [
#                     -1980358.426000001,
#                     -403775.5175999999
#                 ],
#                 [
#                     -1980527.2102000006,
#                     -403788.1199999992
#                 ],
#                 [
#                     -1980759.5112999994,
#                     -403845.0376999993
#                 ],
#                 [
#                     -1980898.0821000002,
#                     -403902.4489999991
#                 ],
#                 [
#                     -1981008.9392000008,
#                     -403918.33290000074
#                 ],
#                 [
#                     -1981145.9590000007,
#                     -403959.09249999933
#                 ],
#                 [
#                     -1981268.7996999994,
#                     -403989.28639999963
#                 ],
#                 [
#                     -1981454.3210000005,
#                     -404060.1969000008
#                 ],
#                 [
#                     -1981652.3713000007,
#                     -404117.7541000005
#                 ],
#                 [
#                     -1981882.3264000006,
#                     -404164.6779999994
#                 ],
#                 [
#                     -1982110.8538000006,
#                     -404218.6194000002
#                 ],
#                 [
#                     -1982229.2796999998,
#                     -404256.8378999997
#                 ],
#                 [
#                     -1982259.0698000006,
#                     -404384.52329999954
#                 ],
#                 [
#                     -1982236.7537999991,
#                     -404489.9219000004
#                 ],
#                 [
#                     -1982152.4398999996,
#                     -404557.67229999974
#                 ],
#                 [
#                     -1982037.5899999999,
#                     -404601.8055000007
#                 ],
#                 [
#                     -1981910.8720999993,
#                     -404662.0879999995
#                 ],
#                 [
#                     -1981798.632099999,
#                     -404771.1911999993
#                 ],
#                 [
#                     -1981698.4901,
#                     -404918.5814999994
#                 ],
#                 [
#                     -1981633.0302000009,
#                     -405134.05700000003
#                 ],
#                 [
#                     -1981580.1258000005,
#                     -405457.0462999996
#                 ],
#                 [
#                     -1981573.9995000008,
#                     -405765.7937000003
#                 ],
#                 [
#                     -1981541.3824000005,
#                     -406014.8783999998
#                 ],
#                 [
#                     -1981577.8390999995,
#                     -406130.83029999956
#                 ],
#                 [
#                     -1981691.0253999997,
#                     -406280.5778999999
#                 ],
#                 [
#                     -1981819.6861000005,
#                     -406402.8161999993
#                 ],
#                 [
#                     -1982044.4290999994,
#                     -406561.24709999934
#                 ],
#                 [
#                     -1982355.8564999998,
#                     -406796.2692000009
#                 ],
#                 [
#                     -1982676.0219999999,
#                     -406988.09600000083
#                 ],
#                 [
#                     -1982922.2860000003,
#                     -407144.9138999991
#                 ],
#                 [
#                     -1983124.927100001,
#                     -407329.36759999953
#                 ],
#                 [
#                     -1983241.8772,
#                     -407481.7564000003
#                 ],
#                 [
#                     -1983323.6012999993,
#                     -407590.4933000002
#                 ],
#                 [
#                     -1983539.4439000003,
#                     -407751.1735999994
#                 ],
#                 [
#                     -1983674.0037999991,
#                     -407871.8443
#                 ],
#                 [
#                     -1983773.2558999993,
#                     -408042.23330000043
#                 ],
#                 [
#                     -1983813.5614999998,
#                     -408188.04030000046
#                 ],
#                 [
#                     -1983832.382099999,
#                     -408335.74430000037
#                 ],
#                 [
#                     -1983800.0431999993,
#                     -408505.44030000083
#                 ],
#                 [
#                     -1983746.7750000004,
#                     -408652.56870000064
#                 ],
#                 [
#                     -1983750.5201999992,
#                     -408775.86759999953
#                 ],
#                 [
#                     -1983763.1060000006,
#                     -408883.4124999996
#                 ],
#                 [
#                     -1983766.8564,
#                     -408911.3372000009
#                 ],
#                 [
#                     -1983784.216,
#                     -409040.84259999916
#                 ],
#                 [
#                     -1983810.4978,
#                     -409193.59970000014
#                 ],
#                 [
#                     -1983849.6689,
#                     -409388.24420000054
#                 ],
#                 [
#                     -1983849.6986999996,
#                     -409388.4754000008
#                 ],
#                 [
#                     -1983858.4207000006,
#                     -409479.38120000064
#                 ],
#                 [
#                     -1983858.517000001,
#                     -409479.9438000005
#                 ],
#                 [
#                     -1983873.9024999999,
#                     -409572.4991999995
#                 ],
#                 [
#                     -1983893.4421999995,
#                     -409723.26659999974
#                 ],
#                 [
#                     -1983943.9287,
#                     -409939.4079
#                 ],
#                 [
#                     -1983944.0141000003,
#                     -409939.6252999995
#                 ],
#                 [
#                     -1983944.1203000005,
#                     -409939.9241000004
#                 ],
#                 [
#                     -1984027.0266999993,
#                     -410147.9184000008
#                 ],
#                 [
#                     -1984078.9430999998,
#                     -410245.84520000033
#                 ],
#                 [
#                     -1984105.2683000006,
#                     -410295.49620000087
#                 ],
#                 [
#                     -1984185.788899999,
#                     -410439.3487999998
#                 ],
#                 [
#                     -1984198.0932,
#                     -410456.2718000002
#                 ],
#                 [
#                     -1984240.8248999994,
#                     -410515.49259999953
#                 ],
#                 [
#                     -1984241.1752000004,
#                     -410515.9782999996
#                 ],
#                 [
#                     -1984269.0160000008,
#                     -410554.48790000007
#                 ],
#                 [
#                     -1984275.3960999995,
#                     -410562.42339999974
#                 ],
#                 [
#                     -1984343.9695999995,
#                     -410647.75210000016
#                 ],
#                 [
#                     -1984466.6446000002,
#                     -410771.05120000057
#                 ],
#                 [
#                     -1984584.9091999996,
#                     -410888.8830999993
#                 ],
#                 [
#                     -1984667.3576999996,
#                     -411000.68930000067
#                 ],
#                 [
#                     -1984682.8244000003,
#                     -411019.6066999994
#                 ],
#                 [
#                     -1984683.1254999992,
#                     -411019.97440000065
#                 ],
#                 [
#                     -1984746.0580000002,
#                     -411096.6115000006
#                 ],
#                 [
#                     -1984812.6601999998,
#                     -411167.46389999986
#                 ],
#                 [
#                     -1984908.4836,
#                     -411269.53839999996
#                 ],
#                 [
#                     -1985039.2817000002,
#                     -411387.5047999993
#                 ],
#                 [
#                     -1985158.2829,
#                     -411457.9615000002
#                 ],
#                 [
#                     -1985158.8136,
#                     -411458.2694000006
#                 ],
#                 [
#                     -1985202.7504999992,
#                     -411484.3929999992
#                 ],
#                 [
#                     -1985289.698999999,
#                     -411497.0616999995
#                 ],
#                 [
#                     -1985348.5390000008,
#                     -411505.6392000001
#                 ],
#                 [
#                     -1985581.866800001,
#                     -411496.14360000007
#                 ],
#                 [
#                     -1985582.1007000003,
#                     -411496.13800000027
#                 ],
#                 [
#                     -1985584.0973000005,
#                     -411495.9671
#                 ],
#                 [
#                     -1985749.1223000009,
#                     -411492.38350000046
#                 ],
#                 [
#                     -1985829.6937000006,
#                     -411482.65210000053
#                 ],
#                 [
#                     -1985830.1225000005,
#                     -411482.6059000008
#                 ],
#                 [
#                     -1985870.8911000006,
#                     -411477.7281999998
#                 ],
#                 [
#                     -1985977.1194000002,
#                     -411463.5987999998
#                 ],
#                 [
#                     -1985977.6775000002,
#                     -411463.59479999915
#                 ],
#                 [
#                     -1986042.5061000008,
#                     -411462.17650000006
#                 ],
#                 [
#                     -1986164.3277000003,
#                     -411447.7673000004
#                 ],
#                 [
#                     -1986220.9386,
#                     -411434.55140000023
#                 ],
#                 [
#                     -1986270.5318,
#                     -411423.1486000009
#                 ],
#                 [
#                     -1986270.6503999997,
#                     -411423.11759999953
#                 ],
#                 [
#                     -1986351.3813000005,
#                     -411404.4480000008
#                 ],
#                 [
#                     -1986437.740700001,
#                     -411369.20680000074
#                 ],
#                 [
#                     -1986437.9081999995,
#                     -411369.13079999946
#                 ],
#                 [
#                     -1986565.5910999998,
#                     -411316.7404999994
#                 ],
#                 [
#                     -1986788.2776999995,
#                     -411265.1372999996
#                 ],
#                 [
#                     -1986958.4546000008,
#                     -411201.0499000009
#                 ],
#                 [
#                     -1987027.0560999997,
#                     -411175.3956000004
#                 ],
#                 [
#                     -1987178.7705000006,
#                     -411089.29560000077
#                 ],
#                 [
#                     -1987298.9823000003,
#                     -411039.9254999999
#                 ],
#                 [
#                     -1987386.6132999994,
#                     -411026.4558000006
#                 ],
#                 [
#                     -1987406.5902999993,
#                     -411027.11539999954
#                 ],
#                 [
#                     -1987406.7171,
#                     -411027.11539999954
#                 ],
#                 [
#                     -1987407.1202000007,
#                     -411027.11920000054
#                 ],
#                 [
#                     -1987425.0362,
#                     -411027.5518999994
#                 ],
#                 [
#                     -1987465.3805999998,
#                     -411028.7570999991
#                 ],
#                 [
#                     -1987639.5930000003,
#                     -410957.3016999997
# ...
#                     -384959.4812000003
#                 ],
#                 [
#                     -2025272.8728,
#                     -384858.9232999999
#                 ],
#                 [
#                     -2025247.7710999995,
#                     -384778.4475999996
#                 ],
#                 [
#                     -2025296.8067000005,
#                     -384680.61370000057
#                 ],
#                 [
#                     -2025428.2401,
#                     -384560.48420000076
#                 ],
#                 [
#                     -2025576.1384999994,
#                     -384457.20940000005
#                 ],
#                 [
#                     -2025748.0886000004,
#                     -384389.80399999954
#                 ],
#                 [
#                     -2025892.3244000003,
#                     -384297.6062000003
#                 ],
#                 [
#                     -2025990.2602999993,
#                     -384274.85979999974
#                 ],
#                 [
#                     -2026146.4923,
#                     -384193.7128999997
#                 ],
#                 [
#                     -2026277.2400000002,
#                     -384083.9968999997
#                 ],
#                 [
#                     -2026376.1027000006,
#                     -383985.2050000001
#                 ],
#                 [
#                     -2026448.7267000005,
#                     -383854.5376999993
#                 ],
#                 [
#                     -2026471.4277,
#                     -383711.0505999997
#                 ],
#                 [
#                     -2026399.1689999998,
#                     -383589.6453000009
#                 ],
#                 [
#                     -2026253.0555000007,
#                     -383433.5052000005
#                 ],
#                 [
#                     -2026103.7508000005,
#                     -383343.95040000044
#                 ],
#                 [
#                     -2025934.9396000002,
#                     -383237.9587999992
#                 ],
#                 [
#                     -2025746.9963000007,
#                     -383157.0212999992
#                 ],
#                 [
#                     -2025436.7885999996,
#                     -383021.7605000008
#                 ],
#                 [
#                     -2025213.7642,
#                     -382911.19480000064
#                 ],
#                 [
#                     -2025064.3190000001,
#                     -382807.5976
#                 ],
#                 [
#                     -2024972.0908000004,
#                     -382707.9143000003
#                 ],
#                 [
#                     -2024880.6841000002,
#                     -382411.38159999996
#                 ],
#                 [
#                     -2024841.6745999996,
#                     -382164.8813000005
#                 ],
#                 [
#                     -2024825.1667999998,
#                     -382040.94659999944
#                 ],
#                 [
#                     -2024853.8826000001,
#                     -381803.02050000057
#                 ],
#                 [
#                     -2024882.5368000008,
#                     -381564.81629999913
#                 ],
#                 [
#                     -2024892.2435999997,
#                     -381272.5666000005
#                 ],
#                 [
#                     -2024874.7607000005,
#                     -381024.49450000003
#                 ],
#                 [
#                     -2024783.2355000004,
#                     -380807.55790000036
#                 ],
#                 [
#                     -2024685.007099999,
#                     -380695.4605999999
#                 ],
#                 [
#                     -2024552.7800999992,
#                     -380612.00009999983
#                 ],
#                 [
#                     -2024269.6037000008,
#                     -380605.2945000008
#                 ],
#                 [
#                     -2024076.1524999999,
#                     -380674.2982999999
#                 ],
#                 [
#                     -2023790.7164999992,
#                     -380778.17899999954
#                 ],
#                 [
#                     -2023549.2850000001,
#                     -380789.3668000009
#                 ],
#                 [
#                     -2023193.2608000003,
#                     -380792.19370000064
#                 ],
#                 [
#                     -2022945.6791999992,
#                     -380777.23980000056
#                 ],
#                 [
#                     -2022745.8428000007,
#                     -380792.32740000077
#                 ],
#                 [
#                     -2022651.8515000008,
#                     -380759.4331
#                 ],
#                 [
#                     -2022628.9443999995,
#                     -380760.7851999998
#                 ],
#                 [
#                     -2022415.6970000006,
#                     -380772.1384999994
#                 ],
#                 [
#                     -2022268.5355999991,
#                     -380771.6610000003
#                 ],
#                 [
#                     -2022061.2411000002,
#                     -380781.6777999997
#                 ],
#                 [
#                     -2021941.0207000002,
#                     -380776.21350000054
#                 ],
#                 [
#                     -2021642.5010000002,
#                     -380883.01820000075
#                 ],
#                 [
#                     -2021495.1806000005,
#                     -380925.66699999943
#                 ],
#                 [
#                     -2021077.2861000001,
#                     -381046.6478000004
#                 ],
#                 [
#                     -2020493.9412999991,
#                     -381078.02979999967
#                 ],
#                 [
#                     -2020119.523600001,
#                     -381098.53240000084
#                 ],
#                 [
#                     -2019352.4926999994,
#                     -381082.3016999997
#                 ],
#                 [
#                     -2018670.8220000006,
#                     -380970.05790000036
#                 ],
#                 [
#                     -2018583.6572999991,
#                     -380926.1723999996
#                 ],
#                 [
#                     -2018350.5265999995,
#                     -380808.9363000002
#                 ],
#                 [
#                     -2017993.7469999995,
#                     -380608.21839999966
#                 ],
#                 [
#                     -2017840.6786000002,
#                     -380408.8456999995
#                 ],
#                 [
#                     -2017518.3153000008,
#                     -380034.4759999998
#                 ],
#                 [
#                     -2017407.7342000008,
#                     -379856.3333999999
#                 ],
#                 [
#                     -2017297.5286999997,
#                     -379626.28839999996
#                 ],
#                 [
#                     -2017162.9068999998,
#                     -379305.3663999997
#                 ],
#                 [
#                     -2017132.8629,
#                     -379251.1121999994
#                 ],
#                 [
#                     -2017054.4200999998,
#                     -379109.4573999997
#                 ],
#                 [
#                     -2016921.1894000005,
#                     -378981.46499999985
#                 ],
#                 [
#                     -2016711.4855000004,
#                     -378967.7399000004
#                 ],
#                 [
#                     -2016474.2917,
#                     -379050.2885999996
#                 ],
#                 [
#                     -2016319.9143000003,
#                     -379179.30900000036
#                 ],
#                 [
#                     -2016053.521400001,
#                     -379431.12519999966
#                 ],
#                 [
#                     -2015951.3841999993,
#                     -379596.2315999996
#                 ],
#                 [
#                     -2015836.5699000005,
#                     -379747.1779999994
#                 ],
#                 [
#                     -2015770.3231000006,
#                     -379819.25909999944
#                 ],
#                 [
#                     -2015699.4507,
#                     -379896.37319999933
#                 ],
#                 [
#                     -2015619.1023999993,
#                     -380087.6138000004
#                 ],
#                 [
#                     -2015480.6538999993,
#                     -380257.88800000027
#                 ],
#                 [
#                     -2015342.4756000005,
#                     -380362.5063000005
#                 ],
#                 [
#                     -2015105.6686000004,
#                     -380500.31039999984
#                 ],
#                 [
#                     -2014958.9133000001,
#                     -380555.0462999996
#                 ],
#                 [
#                     -2014790.6358000003,
#                     -380718.2464000005
#                 ],
#                 [
#                     -2014670.7433000002,
#                     -380780.7302000001
#                 ],
#                 [
#                     -2014598.2904000003,
#                     -380832.0370000005
#                 ],
#                 [
#                     -2014489.5174000002,
#                     -380902.0033999998
#                 ],
#                 [
#                     -2014290.1282000002,
#                     -380972.3468999993
#                 ],
#                 [
#                     -2014135.0583999995,
#                     -381004.9386999998
#                 ],
#                 [
#                     -2014049.3175000008,
#                     -380972.8604000006
#                 ],
#                 [
#                     -2013961.7020999994,
#                     -380879.1616999991
#                 ],
#                 [
#                     -2013879.2649000008,
#                     -380781.0537999999
#                 ],
#                 [
#                     -2013805.8058000002,
#                     -380694.44040000066
#                 ],
#                 [
#                     -2013674.2835000008,
#                     -380600.5617999993
#                 ],
#                 [
#                     -2013530.5494999997,
#                     -380561.26359999925
#                 ],
#                 [
#                     -2013395.0205000006,
#                     -380623.74010000005
#                 ],
#                 [
#                     -2013315.9091999996,
#                     -380686.79560000077
#                 ],
#                 [
#                     -2013211.7217999995,
#                     -380762.7862999998
#                 ],
#                 [
#                     -2013111.3156000003,
#                     -380855.1815000009
#                 ],
#                 [
#                     -2013026.2510000002,
#                     -381012.9243999999
#                 ],
#                 [
#                     -2012922.8465,
#                     -381199.3724000007
#                 ],
#                 [
#                     -2012789.6878999993,
#                     -381285.3308000006
#                 ],
#                 [
#                     -2012693.8231000006,
#                     -381383.73790000007
#                 ],
#                 [
#                     -2012552.0039000008,
#                     -381406.0627999995
#                 ],
#                 [
#                     -2012352.0576000009,
#                     -381500.78309999965
#                 ],
#                 [
#                     -2012207.7989000008,
#                     -381485.9059999995
#                 ],
#                 [
#                     -2011826.5063000005,
#                     -381688.17720000073
#                 ],
#                 [
#                     -2011627.0066,
#                     -381744.7511
#                 ],
#                 [
#                     -2011472.4087000005,
#                     -381739.18459999934
#                 ],
#                 [
#                     -2011346.5009000003,
#                     -381695.90729999915
#                 ],
#                 [
#                     -2011262.5440999996,
#                     -381604.5917000007
#                 ],
#                 [
#                     -2011203.0869999994,
#                     -381497.5719000008
#                 ],
#                 [
#                     -2011126.6627999991,
#                     -381304.7595000006
#                 ],
#                 [
#                     -2011069.3154000007,
#                     -381193.4495000001
#                 ],
#                 [
#                     -2010979.477499999,
#                     -380996.88379999995
#                 ],
#                 [
#                     -2010910.0030000005,
#                     -380847.0440999996
#                 ],
#                 [
#                     -2010826.0293000005,
#                     -380648.87879999913
#                 ],
#                 [
#                     -2010766.7525999993,
#                     -380462.46079999954
#                 ],
#                 [
#                     -2010681.2892000005,
#                     -380364.7675000001
#                 ],
#                 [
#                     -2010560.9440000001,
#                     -380264.8884999994
#                 ],
#                 [
#                     -2010407.9323999994,
#                     -380172.6190000009
#                 ],
#                 [
#                     -2010225.9876000006,
#                     -380090.3072999995
#                 ],
#                 [
#                     -2010067.5448000003,
#                     -380068.3323999997
#                 ],
#                 [
#                     -2009926.9252000004,
#                     -380149.2390999999
#                 ],
#                 [
#                     -2009834.8394000009,
#                     -380263.77270000055
#                 ],
#                 [
#                     -2009745.8575999998,
#                     -380391.40499999933
#                 ],
#                 [
#                     -2009747.6239999998,
#                     -380532.67679999955
#                 ],
#                 [
#                     -2009747.8165000007,
#                     -380760.6827000007
#                 ],
#                 [
#                     -2009759.2588999998,
#                     -380903.0438000001
#                 ],
#                 [
#                     -2009773.6114000008,
#                     -381138.1107999999
#                 ],
#                 [
#                     -2009700.1190000009,
#                     -381251.73509999923
#                 ],
#                 [
#                     -2009660.8058000002,
#                     -381364.4388999995
#                 ],
#                 [
#                     -2009567.3137999997,
#                     -381486.34369999915
#                 ],
#                 [
#                     -2009502.2972999997,
#                     -381542.72100000083
#                 ],
#                 [
#                     -2009299.3673999999,
#                     -381638.1146000009
#                 ],
#                 [
#                     -2009071.1525999997,
#                     -381732.4474999998
#                 ],
#                 [
#                     -2008727.3680000007,
#                     -381867.5178999994
#                 ],
#                 [
#                     -2008462.2127,
#                     -381991.18569999933
#                 ],
#                 [
#                     -2008268.2365000006,
#                     -382098.0647999998
#                 ],
#                 [
#                     -2008144.9833000004,
#                     -382213.11930000037
#                 ],
#                 [
#                     -2008021.9230000004,
#                     -382355.6473999992
#                 ],
#                 [
#                     -2007961.1658999994,
#                     -382483.7109999992
#                 ],
#                 [
#                     -2007910.3699999992,
#                     -382654.3025000002
#                 ]
#             ]
#         ]
#     }
# }

# %%
# Every feature has a 'geometry' which specifies geo coordinates that make up each geographic thing
# In the case of the wildfire data, most wildfires are bounded shapes, circles, squares, etc. This is
# represented by shapes called 'rings' in GeoJSON.

# Get the geometry for the feature we pulled from the feature_list
gj_geometry = gj_feature['geometry']
# The largest shape (ring) is supposed to be item zero in the list of 'rings'
gj_bigest_ring = gj_geometry['rings'][0]

print(f"The largest ring of gj_feature['features'][{SLOT}]['rings'] consists of {len(gj_bigest_ring)} points.")
# Out:
# The largest ring of gj_feature['features'][0]['rings'] consists of 1132 points.

# %% [markdown]
# ## Load the wildfire data using the WildFire Reader module

# %% [markdown]
# In the following cells we provide small code snippets that do the following:
#
# Create a wildfire Reader() object and use it to open the sample data file. Once, opened, we have access to the header information so we print that to show the structure of that data.
# Use the Reader() object and the next() method to read a set of wildfire features. The small sample file should have 13 of them.
# Print one example feature showing the dictionary data structure of a feature.
# Access the geometry of one specific feature to get the 'ring' boundary of that specific fire - which is a list of geodetic coordinates.
# Note that some of the output cells are quite long. Once you understand what they are illustrating you might want to collapse them or comment out the print statements that generate the output.
#
# Another note regarding terminology. In the GeoJSON standard, something that is to be represented geographically is generically called a 'feature'. In the case of the wildfire dataset every 'feature' is a wildfire. These terms are used somewhat interchangably below.

# %% [markdown]
# We are using the custom-built model, from the wildfire module to read the metadata of the JSON to understand the underlying metadata

# %%
print(f"Attempting to open '{EXTRACT_FILENAME}' with wildfire.Reader() object")
wfreader = WFReader(EXTRACT_FILENAME)
print()

header_dict = wfreader.header()
header_keys = list(header_dict.keys())
#print("The header has the following keys:")
#print(gj_keys)
print()
print("Header Dictionary")
print(json.dumps(header_dict,indent=4))
# Out:
# Attempting to open 'C:\Users\shwet\Downloads\GeoJSON Files\GeoJSON Exports\USGS_Wildland_Fire_Combined_Dataset.json' with wildfire.Reader() object
#
#
# Header Dictionary
# {
#     "displayFieldName": "",
#     "fieldAliases": {
#         "OBJECTID": "OBJECTID",
#         "USGS_Assigned_ID": "USGS Assigned ID",
#         "Assigned_Fire_Type": "Assigned Fire Type",
#         "Fire_Year": "Fire Year",
#         "Fire_Polygon_Tier": "Fire Polygon Tier",
#         "Fire_Attribute_Tiers": "Fire Attribute Tiers",
#         "GIS_Acres": "GIS_Acres",
#         "GIS_Hectares": "GIS_Hectares",
#         "Source_Datasets": "Source Datasets",
#         "Listed_Fire_Types": "Listed Fire Types",
#         "Listed_Fire_Names": "Listed Fire Names",
#         "Listed_Fire_Codes": "Listed Fire Codes",
#         "Listed_Fire_IDs": "Listed Fire IDs",
#         "Listed_Fire_IRWIN_IDs": "Listed Fire IRWIN IDs",
#         "Listed_Fire_Dates": "Listed Fire Dates",
#         "Listed_Fire_Causes": "Listed Fire Causes",
#         "Listed_Fire_Cause_Class": "Listed Fire Cause Class",
#         "Listed_Rx_Reported_Acres": "Listed Rx Reported Acres",
#         "Listed_Map_Digitize_Methods": "Listed Map Digitize Methods",
#         "Listed_Notes": "Listed Notes",
#         "Processing_Notes": "Processing Notes",
#         "Wildfire_Notice": "Wildfire Notice",
#         "Prescribed_Burn_Notice": "Prescribed Burn Notice",
#         "Wildfire_and_Rx_Flag": "Wildfire and Rx Flag",
#         "Overlap_Within_1_or_2_Flag": "Overlap Within 1 or 2 Years Flag",
#         "Circleness_Scale": "Circleness Scale",
#         "Circle_Flag": "Circle Flag",
#         "Exclude_From_Summary_Rasters": "Exclude From Summary Rasters",
#         "Shape_Length": "Shape_Length",
#         "Shape_Area": "Shape_Area"
#     },
#     "geometryType": "esriGeometryPolygon",
#     "spatialReference": {
#         "wkid": 102008,
#         "latestWkid": 102008
#     },
#     "fields": [
#         {
#             "name": "OBJECTID",
#             "type": "esriFieldTypeOID",
#             "alias": "OBJECTID"
#         },
#         {
#             "name": "USGS_Assigned_ID",
#             "type": "esriFieldTypeInteger",
#             "alias": "USGS Assigned ID"
#         },
#         {
#             "name": "Assigned_Fire_Type",
#             "type": "esriFieldTypeString",
#             "alias": "Assigned Fire Type",
#             "length": 100
#         },
#         {
#             "name": "Fire_Year",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Fire Year"
#         },
#         {
#             "name": "Fire_Polygon_Tier",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Fire Polygon Tier"
#         },
#         {
#             "name": "Fire_Attribute_Tiers",
#             "type": "esriFieldTypeString",
#             "alias": "Fire Attribute Tiers",
#             "length": 30000
#         },
#         {
#             "name": "GIS_Acres",
#             "type": "esriFieldTypeDouble",
#             "alias": "GIS_Acres"
#         },
#         {
#             "name": "GIS_Hectares",
#             "type": "esriFieldTypeDouble",
#             "alias": "GIS_Hectares"
#         },
#         {
#             "name": "Source_Datasets",
#             "type": "esriFieldTypeString",
#             "alias": "Source Datasets",
#             "length": 500000
#         },
#         {
#             "name": "Listed_Fire_Types",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Types",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Names",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Names",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Codes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Codes",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_IDs",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire IDs",
#             "length": 30000
#         },
#         {
#             "name": "Listed_Fire_IRWIN_IDs",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire IRWIN IDs",
#             "length": 30000
#         },
#         {
#             "name": "Listed_Fire_Dates",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Dates",
#             "length": 500000
#         },
#         {
#             "name": "Listed_Fire_Causes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Causes",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Cause_Class",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Cause Class",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Rx_Reported_Acres",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Rx Reported Acres",
#             "length": 10000
#         },
#         {
#             "name": "Listed_Map_Digitize_Methods",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Map Digitize Methods",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Notes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Notes",
#             "length": 30000
#         },
#         {
#             "name": "Processing_Notes",
#             "type": "esriFieldTypeString",
#             "alias": "Processing Notes",
#             "length": 30000
#         },
#         {
#             "name": "Wildfire_Notice",
#             "type": "esriFieldTypeString",
#             "alias": "Wildfire Notice",
#             "length": 700
#         },
#         {
#             "name": "Prescribed_Burn_Notice",
#             "type": "esriFieldTypeString",
#             "alias": "Prescribed Burn Notice",
#             "length": 700
#         },
#         {
#             "name": "Wildfire_and_Rx_Flag",
#             "type": "esriFieldTypeString",
#             "alias": "Wildfire and Rx Flag",
#             "length": 1000
#         },
#         {
#             "name": "Overlap_Within_1_or_2_Flag",
#             "type": "esriFieldTypeString",
#             "alias": "Overlap Within 1 or 2 Years Flag",
#             "length": 8000
#         },
#         {
#             "name": "Circleness_Scale",
#             "type": "esriFieldTypeDouble",
#             "alias": "Circleness Scale"
#         },
#         {
#             "name": "Circle_Flag",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Circle Flag"
#         },
#         {
#             "name": "Exclude_From_Summary_Rasters",
#             "type": "esriFieldTypeString",
#             "alias": "Exclude From Summary Rasters",
#             "length": 3
#         },
#         {
#             "name": "Shape_Length",
#             "type": "esriFieldTypeDouble",
#             "alias": "Shape_Length"
#         },
#         {
#             "name": "Shape_Area",
#             "type": "esriFieldTypeDouble",
#             "alias": "Shape_Area"
#         }
#     ]
# }

# %% [markdown]
# Now we will load all the features of our dataset. The GeoJson contains information of all the fires from 1880s till the current date. This blows up the size of the data and makes it hard for the system to read it directly. Hence, here, we are storing all the wildfire features in a list for easy access. We are also logging the number of features processed

# %%
#
#    This sample code will load the whole sample file, or a small amount of the complete dataset.
#
MAX_FEATURE_LOAD = 100
feature_list = list()
feature_count = 0
# A rewind() on the reader object makes sure we're at the start of the feature list
# This way, we can execute this cell multiple times and get the same result 
wfreader.rewind()
# Now, read through each of the features, saving them as dictionaries into a list
feature = wfreader.next()
while feature:
    feature_list.append(feature)
    feature_count += 1
    # if we're loading a lot of features, print progress
    if (feature_count % 100) == 0:
        print(f"Loaded {feature_count} features")
   
    feature = wfreader.next()
#
#    Print the number of items (features) we think we loaded
print(f"Loaded a total of {feature_count} features")
#
#    Just a validation check - did all the items we loaded get into the list?
print(f"Variable 'feature_list' contains {len(feature_list)} features")
# Out:
# Loaded 100 features
# Loaded 200 features
# Loaded 300 features
# Loaded 400 features
# Loaded 500 features
# Loaded 600 features
# Loaded 700 features
# Loaded 800 features
# Loaded 900 features
# Loaded 1000 features
# Loaded 1100 features
# Loaded 1200 features
# Loaded 1300 features
# Loaded 1400 features
# Loaded 1500 features
# Loaded 1600 features
# Loaded 1700 features
# Loaded 1800 features
# Loaded 1900 features
# Loaded 2000 features
# Loaded 2100 features
# Loaded 2200 features
# Loaded 2300 features
# Loaded 2400 features
# Loaded 2500 features
# Loaded 2600 features
# Loaded 2700 features
# Loaded 2800 features
# Loaded 2900 features
# Loaded 3000 features
# Loaded 3100 features
# Loaded 3200 features
# Loaded 3300 features
# Loaded 3400 features
# Loaded 3500 features
# Loaded 3600 features
# Loaded 3700 features
# Loaded 3800 features
# Loaded 3900 features
# Loaded 4000 features
# Loaded 4100 features
# Loaded 4200 features
# Loaded 4300 features
# Loaded 4400 features
# Loaded 4500 features
# Loaded 4600 features
# Loaded 4700 features
# Loaded 4800 features
# Loaded 4900 features
# Loaded 5000 features
# Loaded 5100 features
# Loaded 5200 features
# Loaded 5300 features
# Loaded 5400 features
# Loaded 5500 features
# Loaded 5600 features
# Loaded 5700 features
# Loaded 5800 features
# Loaded 5900 features
# Loaded 6000 features
# Loaded 6100 features
# Loaded 6200 features
# Loaded 6300 features
# Loaded 6400 features
# Loaded 6500 features
# Loaded 6600 features
# Loaded 6700 features
# Loaded 6800 features
# Loaded 6900 features
# Loaded 7000 features
# Loaded 7100 features
# Loaded 7200 features
# Loaded 7300 features
# Loaded 7400 features
# Loaded 7500 features
# Loaded 7600 features
# Loaded 7700 features
# Loaded 7800 features
# Loaded 7900 features
# Loaded 8000 features
# Loaded 8100 features
# Loaded 8200 features
# Loaded 8300 features
# Loaded 8400 features
# Loaded 8500 features
# Loaded 8600 features
# Loaded 8700 features
# Loaded 8800 features
# Loaded 8900 features
# Loaded 9000 features
# Loaded 9100 features
# Loaded 9200 features
# Loaded 9300 features
# Loaded 9400 features
# Loaded 9500 features
# Loaded 9600 features
# Loaded 9700 features
# Loaded 9800 features
# Loaded 9900 features
# Loaded 10000 features
# Loaded 10100 features
# Loaded 10200 features
# Loaded 10300 features
# Loaded 10400 features
# Loaded 10500 features
# Loaded 10600 features
# Loaded 10700 features
# Loaded 10800 features
# Loaded 10900 features
# Loaded 11000 features
# Loaded 11100 features
# Loaded 11200 features
# Loaded 11300 features
# Loaded 11400 features
# Loaded 11500 features
# Loaded 11600 features
# Loaded 11700 features
# Loaded 11800 features
# Loaded 11900 features
# Loaded 12000 features
# Loaded 12100 features
# Loaded 12200 features
# Loaded 12300 features
# Loaded 12400 features
# Loaded 12500 features
# Loaded 12600 features
# Loaded 12700 features
# Loaded 12800 features
# Loaded 12900 features
# Loaded 13000 features
# Loaded 13100 features
# Loaded 13200 features
# Loaded 13300 features
# Loaded 13400 features
# Loaded 13500 features
# Loaded 13600 features
# Loaded 13700 features
# Loaded 13800 features
# Loaded 13900 features
# Loaded 14000 features
# Loaded 14100 features
# Loaded 14200 features
# Loaded 14300 features
# Loaded 14400 features
# Loaded 14500 features
# Loaded 14600 features
# Loaded 14700 features
# Loaded 14800 features
# Loaded 14900 features
# Loaded 15000 features
# Loaded 15100 features
# Loaded 15200 features
# Loaded 15300 features
# Loaded 15400 features
# Loaded 15500 features
# Loaded 15600 features
# Loaded 15700 features
# Loaded 15800 features
# Loaded 15900 features
# Loaded 16000 features
# Loaded 16100 features
# Loaded 16200 features
# Loaded 16300 features
# Loaded 16400 features
# Loaded 16500 features
# Loaded 16600 features
# Loaded 16700 features
# Loaded 16800 features
# Loaded 16900 features
# Loaded 17000 features
# Loaded 17100 features
# Loaded 17200 features
# Loaded 17300 features
# Loaded 17400 features
# Loaded 17500 features
# Loaded 17600 features
# Loaded 17700 features
# Loaded 17800 features
# Loaded 17900 features
# Loaded 18000 features
# Loaded 18100 features
# Loaded 18200 features
# Loaded 18300 features
# Loaded 18400 features
# Loaded 18500 features
# Loaded 18600 features
# Loaded 18700 features
# Loaded 18800 features
# Loaded 18900 features
# Loaded 19000 features
# Loaded 19100 features
# Loaded 19200 features
# Loaded 19300 features
# Loaded 19400 features
# Loaded 19500 features
# Loaded 19600 features
# Loaded 19700 features
# Loaded 19800 features
# Loaded 19900 features
# Loaded 20000 features
# Loaded 20100 features
# Loaded 20200 features
# Loaded 20300 features
# Loaded 20400 features
# Loaded 20500 features
# Loaded 20600 features
# Loaded 20700 features
# Loaded 20800 features
# Loaded 20900 features
# Loaded 21000 features
# Loaded 21100 features
# Loaded 21200 features
# Loaded 21300 features
# Loaded 21400 features
# Loaded 21500 features
# Loaded 21600 features
# Loaded 21700 features
# Loaded 21800 features
# Loaded 21900 features
# Loaded 22000 features
# Loaded 22100 features
# Loaded 22200 features
# Loaded 22300 features
# Loaded 22400 features
# Loaded 22500 features
# Loaded 22600 features
# Loaded 22700 features
# Loaded 22800 features
# Loaded 22900 features
# Loaded 23000 features
# Loaded 23100 features
# Loaded 23200 features
# Loaded 23300 features
# Loaded 23400 features
# Loaded 23500 features
# Loaded 23600 features
# Loaded 23700 features
# Loaded 23800 features
# Loaded 23900 features
# Loaded 24000 features
# Loaded 24100 features
# Loaded 24200 features
# Loaded 24300 features
# Loaded 24400 features
# Loaded 24500 features
# Loaded 24600 features
# Loaded 24700 features
# Loaded 24800 features
# Loaded 24900 features
# Loaded 25000 features
# Loaded 25100 features
# Loaded 25200 features
# Loaded 25300 features
# Loaded 25400 features
# Loaded 25500 features
# Loaded 25600 features
# Loaded 25700 features
# Loaded 25800 features
# Loaded 25900 features
# Loaded 26000 features
# Loaded 26100 features
# Loaded 26200 features
# Loaded 26300 features
# Loaded 26400 features
# Loaded 26500 features
# Loaded 26600 features
# Loaded 26700 features
# Loaded 26800 features
# Loaded 26900 features
# Loaded 27000 features
# Loaded 27100 features
# Loaded 27200 features
# Loaded 27300 features
# Loaded 27400 features
# Loaded 27500 features
# Loaded 27600 features
# Loaded 27700 features
# Loaded 27800 features
# Loaded 27900 features
# Loaded 28000 features
# Loaded 28100 features
# Loaded 28200 features
# Loaded 28300 features
# Loaded 28400 features
# Loaded 28500 features
# Loaded 28600 features
# Loaded 28700 features
# Loaded 28800 features
# Loaded 28900 features
# Loaded 29000 features
# Loaded 29100 features
# Loaded 29200 features
# Loaded 29300 features
# Loaded 29400 features
# Loaded 29500 features
# Loaded 29600 features
# Loaded 29700 features
# Loaded 29800 features
# Loaded 29900 features
# Loaded 30000 features
# Loaded 30100 features
# Loaded 30200 features
# Loaded 30300 features
# Loaded 30400 features
# Loaded 30500 features
# Loaded 30600 features
# Loaded 30700 features
# Loaded 30800 features
# Loaded 30900 features
# Loaded 31000 features
# Loaded 31100 features
# Loaded 31200 features
# Loaded 31300 features
# Loaded 31400 features
# Loaded 31500 features
# Loaded 31600 features
# Loaded 31700 features
# Loaded 31800 features
# Loaded 31900 features
# Loaded 32000 features
# Loaded 32100 features
# Loaded 32200 features
# Loaded 32300 features
# Loaded 32400 features
# Loaded 32500 features
# Loaded 32600 features
# Loaded 32700 features
# Loaded 32800 features
# Loaded 32900 features
# Loaded 33000 features
# Loaded 33100 features
# Loaded 33200 features
# Loaded 33300 features
# Loaded 33400 features
# Loaded 33500 features
# Loaded 33600 features
# Loaded 33700 features
# Loaded 33800 features
# Loaded 33900 features
# Loaded 34000 features
# Loaded 34100 features
# Loaded 34200 features
# Loaded 34300 features
# Loaded 34400 features
# Loaded 34500 features
# Loaded 34600 features
# Loaded 34700 features
# Loaded 34800 features
# Loaded 34900 features
# Loaded 35000 features
# Loaded 35100 features
# Loaded 35200 features
# Loaded 35300 features
# Loaded 35400 features
# Loaded 35500 features
# Loaded 35600 features
# Loaded 35700 features
# Loaded 35800 features
# Loaded 35900 features
# Loaded 36000 features
# Loaded 36100 features
# Loaded 36200 features
# Loaded 36300 features
# Loaded 36400 features
# Loaded 36500 features
# Loaded 36600 features
# Loaded 36700 features
# Loaded 36800 features
# Loaded 36900 features
# Loaded 37000 features
# Loaded 37100 features
# Loaded 37200 features
# Loaded 37300 features
# Loaded 37400 features
# Loaded 37500 features
# Loaded 37600 features
# Loaded 37700 features
# Loaded 37800 features
# Loaded 37900 features
# Loaded 38000 features
# Loaded 38100 features
# Loaded 38200 features
# Loaded 38300 features
# Loaded 38400 features
# Loaded 38500 features
# Loaded 38600 features
# Loaded 38700 features
# Loaded 38800 features
# Loaded 38900 features
# Loaded 39000 features
# Loaded 39100 features
# Loaded 39200 features
# Loaded 39300 features
# Loaded 39400 features
# Loaded 39500 features
# Loaded 39600 features
# Loaded 39700 features
# Loaded 39800 features
# Loaded 39900 features
# Loaded 40000 features
# Loaded 40100 features
# Loaded 40200 features
# Loaded 40300 features
# Loaded 40400 features
# Loaded 40500 features
# Loaded 40600 features
# Loaded 40700 features
# Loaded 40800 features
# Loaded 40900 features
# Loaded 41000 features
# Loaded 41100 features
# Loaded 41200 features
# Loaded 41300 features
# Loaded 41400 features
# Loaded 41500 features
# Loaded 41600 features
# Loaded 41700 features
# Loaded 41800 features
# Loaded 41900 features
# Loaded 42000 features
# Loaded 42100 features
# Loaded 42200 features
# Loaded 42300 features
# Loaded 42400 features
# Loaded 42500 features
# Loaded 42600 features
# Loaded 42700 features
# Loaded 42800 features
# Loaded 42900 features
# Loaded 43000 features
# Loaded 43100 features
# Loaded 43200 features
# Loaded 43300 features
# Loaded 43400 features
# Loaded 43500 features
# Loaded 43600 features
# Loaded 43700 features
# Loaded 43800 features
# Loaded 43900 features
# Loaded 44000 features
# Loaded 44100 features
# Loaded 44200 features
# Loaded 44300 features
# Loaded 44400 features
# Loaded 44500 features
# Loaded 44600 features
# Loaded 44700 features
# Loaded 44800 features
# Loaded 44900 features
# Loaded 45000 features
# Loaded 45100 features
# Loaded 45200 features
# Loaded 45300 features
# Loaded 45400 features
# Loaded 45500 features
# Loaded 45600 features
# Loaded 45700 features
# Loaded 45800 features
# Loaded 45900 features
# Loaded 46000 features
# Loaded 46100 features
# Loaded 46200 features
# Loaded 46300 features
# Loaded 46400 features
# Loaded 46500 features
# Loaded 46600 features
# Loaded 46700 features
# Loaded 46800 features
# Loaded 46900 features
# Loaded 47000 features
# Loaded 47100 features
# Loaded 47200 features
# Loaded 47300 features
# Loaded 47400 features
# Loaded 47500 features
# Loaded 47600 features
# Loaded 47700 features
# Loaded 47800 features
# Loaded 47900 features
# Loaded 48000 features
# Loaded 48100 features
# Loaded 48200 features
# Loaded 48300 features
# Loaded 48400 features
# Loaded 48500 features
# Loaded 48600 features
# Loaded 48700 features
# Loaded 48800 features
# Loaded 48900 features
# Loaded 49000 features
# Loaded 49100 features
# Loaded 49200 features
# Loaded 49300 features
# Loaded 49400 features
# Loaded 49500 features
# Loaded 49600 features
# Loaded 49700 features
# Loaded 49800 features
# Loaded 49900 features
# Loaded 50000 features
# Loaded 50100 features
# Loaded 50200 features
# Loaded 50300 features
# Loaded 50400 features
# Loaded 50500 features
# Loaded 50600 features
# Loaded 50700 features
# Loaded 50800 features
# Loaded 50900 features
# Loaded 51000 features
# Loaded 51100 features
# Loaded 51200 features
# Loaded 51300 features
# Loaded 51400 features
# Loaded 51500 features
# Loaded 51600 features
# Loaded 51700 features
# Loaded 51800 features
# Loaded 51900 features
# Loaded 52000 features
# Loaded 52100 features
# Loaded 52200 features
# Loaded 52300 features
# Loaded 52400 features
# Loaded 52500 features
# Loaded 52600 features
# Loaded 52700 features
# Loaded 52800 features
# Loaded 52900 features
# Loaded 53000 features
# Loaded 53100 features
# Loaded 53200 features
# Loaded 53300 features
# Loaded 53400 features
# Loaded 53500 features
# Loaded 53600 features
# Loaded 53700 features
# Loaded 53800 features
# Loaded 53900 features
# Loaded 54000 features
# Loaded 54100 features
# Loaded 54200 features
# Loaded 54300 features
# Loaded 54400 features
# Loaded 54500 features
# Loaded 54600 features
# Loaded 54700 features
# Loaded 54800 features
# Loaded 54900 features
# Loaded 55000 features
# Loaded 55100 features
# Loaded 55200 features
# Loaded 55300 features
# Loaded 55400 features
# Loaded 55500 features
# Loaded 55600 features
# Loaded 55700 features
# Loaded 55800 features
# Loaded 55900 features
# Loaded 56000 features
# Loaded 56100 features
# Loaded 56200 features
# Loaded 56300 features
# Loaded 56400 features
# Loaded 56500 features
# Loaded 56600 features
# Loaded 56700 features
# Loaded 56800 features
# Loaded 56900 features
# Loaded 57000 features
# Loaded 57100 features
# Loaded 57200 features
# Loaded 57300 features
# Loaded 57400 features
# Loaded 57500 features
# Loaded 57600 features
# Loaded 57700 features
# Loaded 57800 features
# Loaded 57900 features
# Loaded 58000 features
# Loaded 58100 features
# Loaded 58200 features
# Loaded 58300 features
# Loaded 58400 features
# Loaded 58500 features
# Loaded 58600 features
# Loaded 58700 features
# Loaded 58800 features
# Loaded 58900 features
# Loaded 59000 features
# Loaded 59100 features
# Loaded 59200 features
# Loaded 59300 features
# Loaded 59400 features
# Loaded 59500 features
# Loaded 59600 features
# Loaded 59700 features
# Loaded 59800 features
# Loaded 59900 features
# Loaded 60000 features
# Loaded 60100 features
# Loaded 60200 features
# Loaded 60300 features
# Loaded 60400 features
# Loaded 60500 features
# Loaded 60600 features
# Loaded 60700 features
# Loaded 60800 features
# Loaded 60900 features
# Loaded 61000 features
# Loaded 61100 features
# Loaded 61200 features
# Loaded 61300 features
# Loaded 61400 features
# Loaded 61500 features
# Loaded 61600 features
# Loaded 61700 features
# Loaded 61800 features
# Loaded 61900 features
# Loaded 62000 features
# Loaded 62100 features
# Loaded 62200 features
# Loaded 62300 features
# Loaded 62400 features
# Loaded 62500 features
# Loaded 62600 features
# Loaded 62700 features
# Loaded 62800 features
# Loaded 62900 features
# Loaded 63000 features
# Loaded 63100 features
# Loaded 63200 features
# Loaded 63300 features
# Loaded 63400 features
# Loaded 63500 features
# Loaded 63600 features
# Loaded 63700 features
# Loaded 63800 features
# Loaded 63900 features
# Loaded 64000 features
# Loaded 64100 features
# Loaded 64200 features
# Loaded 64300 features
# Loaded 64400 features
# Loaded 64500 features
# Loaded 64600 features
# Loaded 64700 features
# Loaded 64800 features
# Loaded 64900 features
# Loaded 65000 features
# Loaded 65100 features
# Loaded 65200 features
# Loaded 65300 features
# Loaded 65400 features
# Loaded 65500 features
# Loaded 65600 features
# Loaded 65700 features
# Loaded 65800 features
# Loaded 65900 features
# Loaded 66000 features
# Loaded 66100 features
# Loaded 66200 features
# Loaded 66300 features
# Loaded 66400 features
# Loaded 66500 features
# Loaded 66600 features
# Loaded 66700 features
# Loaded 66800 features
# Loaded 66900 features
# Loaded 67000 features
# Loaded 67100 features
# Loaded 67200 features
# Loaded 67300 features
# Loaded 67400 features
# Loaded 67500 features
# Loaded 67600 features
# Loaded 67700 features
# Loaded 67800 features
# Loaded 67900 features
# Loaded 68000 features
# Loaded 68100 features
# Loaded 68200 features
# Loaded 68300 features
# Loaded 68400 features
# Loaded 68500 features
# Loaded 68600 features
# Loaded 68700 features
# Loaded 68800 features
# Loaded 68900 features
# Loaded 69000 features
# Loaded 69100 features
# Loaded 69200 features
# Loaded 69300 features
# Loaded 69400 features
# Loaded 69500 features
# Loaded 69600 features
# Loaded 69700 features
# Loaded 69800 features
# Loaded 69900 features
# Loaded 70000 features
# Loaded 70100 features
# Loaded 70200 features
# Loaded 70300 features
# Loaded 70400 features
# Loaded 70500 features
# Loaded 70600 features
# Loaded 70700 features
# Loaded 70800 features
# Loaded 70900 features
# Loaded 71000 features
# Loaded 71100 features
# Loaded 71200 features
# Loaded 71300 features
# Loaded 71400 features
# Loaded 71500 features
# Loaded 71600 features
# Loaded 71700 features
# Loaded 71800 features
# Loaded 71900 features
# Loaded 72000 features
# Loaded 72100 features
# Loaded 72200 features
# Loaded 72300 features
# Loaded 72400 features
# Loaded 72500 features
# Loaded 72600 features
# Loaded 72700 features
# Loaded 72800 features
# Loaded 72900 features
# Loaded 73000 features
# Loaded 73100 features
# Loaded 73200 features
# Loaded 73300 features
# Loaded 73400 features
# Loaded 73500 features
# Loaded 73600 features
# Loaded 73700 features
# Loaded 73800 features
# Loaded 73900 features
# Loaded 74000 features
# Loaded 74100 features
# Loaded 74200 features
# Loaded 74300 features
# Loaded 74400 features
# Loaded 74500 features
# Loaded 74600 features
# Loaded 74700 features
# Loaded 74800 features
# Loaded 74900 features
# Loaded 75000 features
# Loaded 75100 features
# Loaded 75200 features
# Loaded 75300 features
# Loaded 75400 features
# Loaded 75500 features
# Loaded 75600 features
# Loaded 75700 features
# Loaded 75800 features
# Loaded 75900 features
# Loaded 76000 features
# Loaded 76100 features
# Loaded 76200 features
# Loaded 76300 features
# Loaded 76400 features
# Loaded 76500 features
# Loaded 76600 features
# Loaded 76700 features
# Loaded 76800 features
# Loaded 76900 features
# Loaded 77000 features
# Loaded 77100 features
# Loaded 77200 features
# Loaded 77300 features
# Loaded 77400 features
# Loaded 77500 features
# Loaded 77600 features
# Loaded 77700 features
# Loaded 77800 features
# Loaded 77900 features
# Loaded 78000 features
# Loaded 78100 features
# Loaded 78200 features
# Loaded 78300 features
# Loaded 78400 features
# Loaded 78500 features
# Loaded 78600 features
# Loaded 78700 features
# Loaded 78800 features
# Loaded 78900 features
# Loaded 79000 features
# Loaded 79100 features
# Loaded 79200 features
# Loaded 79300 features
# Loaded 79400 features
# Loaded 79500 features
# Loaded 79600 features
# Loaded 79700 features
# Loaded 79800 features
# Loaded 79900 features
# Loaded 80000 features
# Loaded 80100 features
# Loaded 80200 features
# Loaded 80300 features
# Loaded 80400 features
# Loaded 80500 features
# Loaded 80600 features
# Loaded 80700 features
# Loaded 80800 features
# Loaded 80900 features
# Loaded 81000 features
# Loaded 81100 features
# Loaded 81200 features
# Loaded 81300 features
# Loaded 81400 features
# Loaded 81500 features
# Loaded 81600 features
# Loaded 81700 features
# Loaded 81800 features
# Loaded 81900 features
# Loaded 82000 features
# Loaded 82100 features
# Loaded 82200 features
# Loaded 82300 features
# Loaded 82400 features
# Loaded 82500 features
# Loaded 82600 features
# Loaded 82700 features
# Loaded 82800 features
# Loaded 82900 features
# Loaded 83000 features
# Loaded 83100 features
# Loaded 83200 features
# Loaded 83300 features
# Loaded 83400 features
# Loaded 83500 features
# Loaded 83600 features
# Loaded 83700 features
# Loaded 83800 features
# Loaded 83900 features
# Loaded 84000 features
# Loaded 84100 features
# Loaded 84200 features
# Loaded 84300 features
# Loaded 84400 features
# Loaded 84500 features
# Loaded 84600 features
# Loaded 84700 features
# Loaded 84800 features
# Loaded 84900 features
# Loaded 85000 features
# Loaded 85100 features
# Loaded 85200 features
# Loaded 85300 features
# Loaded 85400 features
# Loaded 85500 features
# Loaded 85600 features
# Loaded 85700 features
# Loaded 85800 features
# Loaded 85900 features
# Loaded 86000 features
# Loaded 86100 features
# Loaded 86200 features
# Loaded 86300 features
# Loaded 86400 features
# Loaded 86500 features
# Loaded 86600 features
# Loaded 86700 features
# Loaded 86800 features
# Loaded 86900 features
# Loaded 87000 features
# Loaded 87100 features
# Loaded 87200 features
# Loaded 87300 features
# Loaded 87400 features
# Loaded 87500 features
# Loaded 87600 features
# Loaded 87700 features
# Loaded 87800 features
# Loaded 87900 features
# Loaded 88000 features
# Loaded 88100 features
# Loaded 88200 features
# Loaded 88300 features
# Loaded 88400 features
# Loaded 88500 features
# Loaded 88600 features
# Loaded 88700 features
# Loaded 88800 features
# Loaded 88900 features
# Loaded 89000 features
# Loaded 89100 features
# Loaded 89200 features
# Loaded 89300 features
# Loaded 89400 features
# Loaded 89500 features
# Loaded 89600 features
# Loaded 89700 features
# Loaded 89800 features
# Loaded 89900 features
# Loaded 90000 features
# Loaded 90100 features
# Loaded 90200 features
# Loaded 90300 features
# Loaded 90400 features
# Loaded 90500 features
# Loaded 90600 features
# Loaded 90700 features
# Loaded 90800 features
# Loaded 90900 features
# Loaded 91000 features
# Loaded 91100 features
# Loaded 91200 features
# Loaded 91300 features
# Loaded 91400 features
# Loaded 91500 features
# Loaded 91600 features
# Loaded 91700 features
# Loaded 91800 features
# Loaded 91900 features
# Loaded 92000 features
# Loaded 92100 features
# Loaded 92200 features
# Loaded 92300 features
# Loaded 92400 features
# Loaded 92500 features
# Loaded 92600 features
# Loaded 92700 features
# Loaded 92800 features
# Loaded 92900 features
# Loaded 93000 features
# Loaded 93100 features
# Loaded 93200 features
# Loaded 93300 features
# Loaded 93400 features
# Loaded 93500 features
# Loaded 93600 features
# Loaded 93700 features
# Loaded 93800 features
# Loaded 93900 features
# Loaded 94000 features
# Loaded 94100 features
# Loaded 94200 features
# Loaded 94300 features
# Loaded 94400 features
# Loaded 94500 features
# Loaded 94600 features
# Loaded 94700 features
# Loaded 94800 features
# Loaded 94900 features
# Loaded 95000 features
# Loaded 95100 features
# Loaded 95200 features
# Loaded 95300 features
# Loaded 95400 features
# Loaded 95500 features
# Loaded 95600 features
# Loaded 95700 features
# Loaded 95800 features
# Loaded 95900 features
# Loaded 96000 features
# Loaded 96100 features
# Loaded 96200 features
# Loaded 96300 features
# Loaded 96400 features
# Loaded 96500 features
# Loaded 96600 features
# Loaded 96700 features
# Loaded 96800 features
# Loaded 96900 features
# Loaded 97000 features
# Loaded 97100 features
# Loaded 97200 features
# Loaded 97300 features
# Loaded 97400 features
# Loaded 97500 features
# Loaded 97600 features
# Loaded 97700 features
# Loaded 97800 features
# Loaded 97900 features
# Loaded 98000 features
# Loaded 98100 features
# Loaded 98200 features
# Loaded 98300 features
# Loaded 98400 features
# Loaded 98500 features
# Loaded 98600 features
# Loaded 98700 features
# Loaded 98800 features
# Loaded 98900 features
# Loaded 99000 features
# Loaded 99100 features
# Loaded 99200 features
# Loaded 99300 features
# Loaded 99400 features
# Loaded 99500 features
# Loaded 99600 features
# Loaded 99700 features
# Loaded 99800 features
# Loaded 99900 features
# Loaded 100000 features
# Loaded 100100 features
# Loaded 100200 features
# Loaded 100300 features
# Loaded 100400 features
# Loaded 100500 features
# Loaded 100600 features
# Loaded 100700 features
# Loaded 100800 features
# Loaded 100900 features
# Loaded 101000 features
# Loaded 101100 features
# Loaded 101200 features
# Loaded 101300 features
# Loaded 101400 features
# Loaded 101500 features
# Loaded 101600 features
# Loaded 101700 features
# Loaded 101800 features
# Loaded 101900 features
# Loaded 102000 features
# Loaded 102100 features
# Loaded 102200 features
# Loaded 102300 features
# Loaded 102400 features
# Loaded 102500 features
# Loaded 102600 features
# Loaded 102700 features
# Loaded 102800 features
# Loaded 102900 features
# Loaded 103000 features
# Loaded 103100 features
# Loaded 103200 features
# Loaded 103300 features
# Loaded 103400 features
# Loaded 103500 features
# Loaded 103600 features
# Loaded 103700 features
# Loaded 103800 features
# Loaded 103900 features
# Loaded 104000 features
# Loaded 104100 features
# Loaded 104200 features
# Loaded 104300 features
# Loaded 104400 features
# Loaded 104500 features
# Loaded 104600 features
# Loaded 104700 features
# Loaded 104800 features
# Loaded 104900 features
# Loaded 105000 features
# Loaded 105100 features
# Loaded 105200 features
# Loaded 105300 features
# Loaded 105400 features
# Loaded 105500 features
# Loaded 105600 features
# Loaded 105700 features
# Loaded 105800 features
# Loaded 105900 features
# Loaded 106000 features
# Loaded 106100 features
# Loaded 106200 features
# Loaded 106300 features
# Loaded 106400 features
# Loaded 106500 features
# Loaded 106600 features
# Loaded 106700 features
# Loaded 106800 features
# Loaded 106900 features
# Loaded 107000 features
# Loaded 107100 features
# Loaded 107200 features
# Loaded 107300 features
# Loaded 107400 features
# Loaded 107500 features
# Loaded 107600 features
# Loaded 107700 features
# Loaded 107800 features
# Loaded 107900 features
# Loaded 108000 features
# Loaded 108100 features
# Loaded 108200 features
# Loaded 108300 features
# Loaded 108400 features
# Loaded 108500 features
# Loaded 108600 features
# Loaded 108700 features
# Loaded 108800 features
# Loaded 108900 features
# Loaded 109000 features
# Loaded 109100 features
# Loaded 109200 features
# Loaded 109300 features
# Loaded 109400 features
# Loaded 109500 features
# Loaded 109600 features
# Loaded 109700 features
# Loaded 109800 features
# Loaded 109900 features
# Loaded 110000 features
# Loaded 110100 features
# Loaded 110200 features
# Loaded 110300 features
# Loaded 110400 features
# Loaded 110500 features
# Loaded 110600 features
# Loaded 110700 features
# Loaded 110800 features
# Loaded 110900 features
# Loaded 111000 features
# Loaded 111100 features
# Loaded 111200 features
# Loaded 111300 features
# Loaded 111400 features
# Loaded 111500 features
# Loaded 111600 features
# Loaded 111700 features
# Loaded 111800 features
# Loaded 111900 features
# Loaded 112000 features
# Loaded 112100 features
# Loaded 112200 features
# Loaded 112300 features
# Loaded 112400 features
# Loaded 112500 features
# Loaded 112600 features
# Loaded 112700 features
# Loaded 112800 features
# Loaded 112900 features
# Loaded 113000 features
# Loaded 113100 features
# Loaded 113200 features
# Loaded 113300 features
# Loaded 113400 features
# Loaded 113500 features
# Loaded 113600 features
# Loaded 113700 features
# Loaded 113800 features
# Loaded 113900 features
# Loaded 114000 features
# Loaded 114100 features
# Loaded 114200 features
# Loaded 114300 features
# Loaded 114400 features
# Loaded 114500 features
# Loaded 114600 features
# Loaded 114700 features
# Loaded 114800 features
# Loaded 114900 features
# Loaded 115000 features
# Loaded 115100 features
# Loaded 115200 features
# Loaded 115300 features
# Loaded 115400 features
# Loaded 115500 features
# Loaded 115600 features
# Loaded 115700 features
# Loaded 115800 features
# Loaded 115900 features
# Loaded 116000 features
# Loaded 116100 features
# Loaded 116200 features
# Loaded 116300 features
# Loaded 116400 features
# Loaded 116500 features
# Loaded 116600 features
# Loaded 116700 features
# Loaded 116800 features
# Loaded 116900 features
# Loaded 117000 features
# Loaded 117100 features
# Loaded 117200 features
# Loaded 117300 features
# Loaded 117400 features
# Loaded 117500 features
# Loaded 117600 features
# Loaded 117700 features
# Loaded 117800 features
# Loaded 117900 features
# Loaded 118000 features
# Loaded 118100 features
# Loaded 118200 features
# Loaded 118300 features
# Loaded 118400 features
# Loaded 118500 features
# Loaded 118600 features
# Loaded 118700 features
# Loaded 118800 features
# Loaded 118900 features
# Loaded 119000 features
# Loaded 119100 features
# Loaded 119200 features
# Loaded 119300 features
# Loaded 119400 features
# Loaded 119500 features
# Loaded 119600 features
# Loaded 119700 features
# Loaded 119800 features
# Loaded 119900 features
# Loaded 120000 features
# Loaded 120100 features
# Loaded 120200 features
# Loaded 120300 features
# Loaded 120400 features
# Loaded 120500 features
# Loaded 120600 features
# Loaded 120700 features
# Loaded 120800 features
# Loaded 120900 features
# Loaded 121000 features
# Loaded 121100 features
# Loaded 121200 features
# Loaded 121300 features
# Loaded 121400 features
# Loaded 121500 features
# Loaded 121600 features
# Loaded 121700 features
# Loaded 121800 features
# Loaded 121900 features
# Loaded 122000 features
# Loaded 122100 features
# Loaded 122200 features
# Loaded 122300 features
# Loaded 122400 features
# Loaded 122500 features
# Loaded 122600 features
# Loaded 122700 features
# Loaded 122800 features
# Loaded 122900 features
# Loaded 123000 features
# Loaded 123100 features
# Loaded 123200 features
# Loaded 123300 features
# Loaded 123400 features
# Loaded 123500 features
# Loaded 123600 features
# Loaded 123700 features
# Loaded 123800 features
# Loaded 123900 features
# Loaded 124000 features
# Loaded 124100 features
# Loaded 124200 features
# Loaded 124300 features
# Loaded 124400 features
# Loaded 124500 features
# Loaded 124600 features
# Loaded 124700 features
# Loaded 124800 features
# Loaded 124900 features
# Loaded 125000 features
# Loaded 125100 features
# Loaded 125200 features
# Loaded 125300 features
# Loaded 125400 features
# Loaded 125500 features
# Loaded 125600 features
# Loaded 125700 features
# Loaded 125800 features
# Loaded 125900 features
# Loaded 126000 features
# Loaded 126100 features
# Loaded 126200 features
# Loaded 126300 features
# Loaded 126400 features
# Loaded 126500 features
# Loaded 126600 features
# Loaded 126700 features
# Loaded 126800 features
# Loaded 126900 features
# Loaded 127000 features
# Loaded 127100 features
# Loaded 127200 features
# Loaded 127300 features
# Loaded 127400 features
# Loaded 127500 features
# Loaded 127600 features
# Loaded 127700 features
# Loaded 127800 features
# Loaded 127900 features
# Loaded 128000 features
# Loaded 128100 features
# Loaded 128200 features
# Loaded 128300 features
# Loaded 128400 features
# Loaded 128500 features
# Loaded 128600 features
# Loaded 128700 features
# Loaded 128800 features
# Loaded 128900 features
# Loaded 129000 features
# Loaded 129100 features
# Loaded 129200 features
# Loaded 129300 features
# Loaded 129400 features
# Loaded 129500 features
# Loaded 129600 features
# Loaded 129700 features
# Loaded 129800 features
# Loaded 129900 features
# Loaded 130000 features
# Loaded 130100 features
# Loaded 130200 features
# Loaded 130300 features
# Loaded 130400 features
# Loaded 130500 features
# Loaded 130600 features
# Loaded 130700 features
# Loaded 130800 features
# Loaded 130900 features
# Loaded 131000 features
# Loaded 131100 features
# Loaded 131200 features
# Loaded 131300 features
# Loaded 131400 features
# Loaded 131500 features
# Loaded 131600 features
# Loaded 131700 features
# Loaded 131800 features
# Loaded 131900 features
# Loaded 132000 features
# Loaded 132100 features
# Loaded 132200 features
# Loaded 132300 features
# Loaded 132400 features
# Loaded 132500 features
# Loaded 132600 features
# Loaded 132700 features
# Loaded 132800 features
# Loaded 132900 features
# Loaded 133000 features
# Loaded 133100 features
# Loaded 133200 features
# Loaded 133300 features
# Loaded 133400 features
# Loaded 133500 features
# Loaded 133600 features
# Loaded 133700 features
# Loaded 133800 features
# Loaded 133900 features
# Loaded 134000 features
# Loaded 134100 features
# Loaded 134200 features
# Loaded 134300 features
# Loaded 134400 features
# Loaded 134500 features
# Loaded 134600 features
# Loaded 134700 features
# Loaded 134800 features
# Loaded 134900 features
# Loaded 135000 features
# Loaded a total of 135061 features
# Variable 'feature_list' contains 135061 features

# %%
# Get the first item in the list of features

SLOT = 0
gj_feature = gj_data['features'][SLOT]

# Print everyting in this dictionary (i.e., gj_feature) - it's long

print(f"The wildfire feature from slot '{SLOT}' of the loaded gj_data['features']")
print(json.dumps(gj_feature, indent=4))
# Out:
# The wildfire feature from slot '0' of the loaded gj_data['features']
# {
#     "attributes": {
#         "OBJECTID": 4956,
#         "USGS_Assigned_ID": 4956,
#         "Assigned_Fire_Type": "Wildfire",
#         "Fire_Year": 1932,
#         "Fire_Polygon_Tier": 1,
#         "Fire_Attribute_Tiers": "1 (1), 3 (3)",
#         "GIS_Acres": 219999.23754748085,
#         "GIS_Hectares": 89030.53273921262,
#         "Source_Datasets": "Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_State_California_Wildfire_Polygons (1)",
#         "Listed_Fire_Types": "Wildfire (3), Likely Wildfire (1)",
#         "Listed_Fire_Names": "MATILIJA (4)",
#         "Listed_Fire_Codes": "No code provided (4)",
#         "Listed_Fire_IDs": "0 (3)",
#         "Listed_Fire_IRWIN_IDs": "",
#         "Listed_Fire_Dates": "Listed Wildfire Discovery Date(s): 1932-09-07 (2) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1), 1932-09-07 - DATE_CUR field (1)",
#         "Listed_Fire_Causes": "9 - Miscellaneous (1)",
#         "Listed_Fire_Cause_Class": "Undetermined (3), Human (1)",
#         "Listed_Rx_Reported_Acres": null,
#         "Listed_Map_Digitize_Methods": "",
#         "Listed_Notes": "",
#         "Processing_Notes": "",
#         "Wildfire_Notice": "Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.",
#         "Prescribed_Burn_Notice": "Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.",
#         "Wildfire_and_Rx_Flag": null,
#         "Overlap_Within_1_or_2_Flag": null,
#         "Circleness_Scale": 0.3264782366249864,
#         "Circle_Flag": null,
#         "Exclude_From_Summary_Rasters": "No",
#         "Shape_Length": 185117.42477003767,
#         "Shape_Area": 890305327.3921262
#     },
#     "geometry": {
#         "rings": [
#             [
#                 [
#                     -2007910.3699999992,
#                     -382654.3025000002
#                 ],
#                 [
#                     -2007886.8686999995,
#                     -382794.5167999994
#                 ],
#                 [
#                     -2007839.7774,
#                     -382860.65750000067
#                 ],
#                 [
#                     -2007747.0418999996,
#                     -382878.7469999995
#                 ],
#                 [
#                     -2007637.0754000004,
#                     -382890.1484999992
#                 ],
#                 [
#                     -2007509.4678000007,
#                     -382919.8149999995
#                 ],
#                 [
#                     -2007230.8179000001,
#                     -382918.86140000075
#                 ],
#                 [
#                     -2006997.5754000004,
#                     -382938.2013000008
#                 ],
#                 [
#                     -2006678.3796999995,
#                     -382991.3883999996
#                 ],
#                 [
#                     -2006383.3211000003,
#                     -383080.7380999997
#                 ],
#                 [
#                     -2006185.9959999993,
#                     -383133.31540000066
#                 ],
#                 [
#                     -2006056.0844999999,
#                     -383153.0189999994
#                 ],
#                 [
#                     -2005936.3957000002,
#                     -383149.6168000009
#                 ],
#                 [
#                     -2005788.2020999994,
#                     -383104.56240000017
#                 ],
#                 [
#                     -2005759.7040999997,
#                     -382969.5127000008
#                 ],
#                 [
#                     -2005755.6585000008,
#                     -382818.49709999934
#                 ],
#                 [
#                     -2005748.1323000006,
#                     -382599.1616999991
#                 ],
#                 [
#                     -2005642.6709000003,
#                     -382402.57660000026
#                 ],
#                 [
#                     -2005445.3391999993,
#                     -382241.15389999934
#                 ],
#                 [
#                     -2005238.8057000004,
#                     -382147.3643999994
#                 ],
#                 [
#                     -2005108.8168000001,
#                     -382153.3060999997
#                 ],
#                 [
#                     -2004884.1992000006,
#                     -382236.2960999999
#                 ],
#                 [
#                     -2004637.9305000007,
#                     -382400.5293000005
#                 ],
#                 [
#                     -2004294.2146000005,
#                     -382549.3323999997
#                 ],
#                 [
#                     -2003946.138699999,
#                     -382719.6355000008
#                 ],
#                 [
#                     -2003683.2166000009,
#                     -382946.4322999995
#                 ],
#                 [
#                     -2003473.7788999993,
#                     -383174.46350000054
#                 ],
#                 [
#                     -2003284.7511,
#                     -383342.6054999996
#                 ],
#                 [
#                     -2003027.9536000006,
#                     -383595.5524000004
#                 ],
#                 [
#                     -2002884.193,
#                     -383756.7580999993
#                 ],
#                 [
#                     -2002573.8531,
#                     -383901.08919999935
#                 ],
#                 [
#                     -2002280.9246999994,
#                     -384093.31570000015
#                 ],
#                 [
#                     -2001930.6833999995,
#                     -384374.7726000007
#                 ],
#                 [
#                     -2001653.2223000005,
#                     -384646.3831999991
#                 ],
#                 [
#                     -2001304.6051000003,
#                     -384948.2324999999
#                 ],
#                 [
#                     -2001039.6743,
#                     -385206.52940000035
#                 ],
#                 [
#                     -2000653.5270000007,
#                     -385561.88269999996
#                 ],
#                 [
#                     -2000486.7490999997,
#                     -385672.38040000014
#                 ],
#                 [
#                     -2000436.8249999993,
#                     -385705.4603000004
#                 ],
#                 [
#                     -2000164.3216999993,
#                     -385851.2587000001
#                 ],
#                 [
#                     -1999989.6903000008,
#                     -385976.1453000009
#                 ],
#                 [
#                     -1999907.0427,
#                     -386035.2603999991
#                 ],
#                 [
#                     -1999715.1412000004,
#                     -386218.04810000025
#                 ],
#                 [
#                     -1999599.7941999994,
#                     -386300.05849999934
#                 ],
#                 [
#                     -1999479.1380000003,
#                     -386372.7006999999
#                 ],
#                 [
#                     -1999376.1298999991,
#                     -386413.8668000009
#                 ],
#                 [
#                     -1999288.241800001,
#                     -386416.29399999976
#                 ],
#                 [
#                     -1999258.0256999992,
#                     -386417.1355000008
#                 ],
#                 [
#                     -1999112.110200001,
#                     -386381.8482000008
#                 ],
#                 [
#                     -1999036.1954999994,
#                     -386257.9835999999
#                 ],
#                 [
#                     -1999020.2397000007,
#                     -386231.81829999946
#                 ],
#                 [
#                     -1998934.7007,
#                     -386091.5452999994
#                 ],
#                 [
#                     -1998897.6489000004,
#                     -385999.99340000004
#                 ],
#                 [
#                     -1998805.398600001,
#                     -385779.4138999991
#                 ],
#                 [
#                     -1998653.0528999995,
#                     -385569.5778999999
#                 ],
#                 [
#                     -1998548.0596999992,
#                     -385428.2207999993
#                 ],
#                 [
#                     -1998359.7133000009,
#                     -385385.4146999996
#                 ],
#                 [
#                     -1998199.9419,
#                     -385384.5145999994
#                 ],
#                 [
#                     -1997986.9109000005,
#                     -385423.3813000005
#                 ],
#                 [
#                     -1997838.197899999,
#                     -385509.8741999995
#                 ],
#                 [
#                     -1997792.4141000006,
#                     -385661.8336999994
#                 ],
#                 [
#                     -1997782.5089999996,
#                     -385833.54360000044
#                 ],
#                 [
#                     -1997801.360200001,
#                     -385980.98790000007
#                 ],
#                 [
#                     -1997792.7942999993,
#                     -386131.6133999992
#                 ],
#                 [
#                     -1997817.9444999993,
#                     -386225.8099000007
#                 ],
#                 [
#                     -1997826.7894000001,
#                     -386317.2138
#                 ],
#                 [
#                     -1997867.5646000002,
#                     -386411.19219999947
#                 ],
#                 [
#                     -1997928.7301000003,
#                     -386552.3772
#                 ],
#                 [
#                     -1997929.1265999991,
#                     -386553.15550000034
#                 ],
#                 [
#                     -1998004.117900001,
#                     -386700.91029999964
#                 ],
#                 [
#                     -1998004.7749000005,
#                     -386701.78360000066
#                 ],
#                 [
#                     -1998103.8946000002,
#                     -386833.18700000085
#                 ],
#                 [
#                     -1998103.9503000006,
#                     -386833.29140000045
#                 ],
#                 [
#                     -1998212.1433000006,
#                     -387015.1004000008
#                 ],
#                 [
#                     -1998275.8600999992,
#                     -387300.9526000004
#                 ],
#                 [
#                     -1998286.1456000004,
#                     -387385.65970000066
#                 ],
#                 [
#                     -1998299.5402000006,
#                     -387495.8869000003
#                 ],
#                 [
#                     -1998190.3226999994,
#                     -387711.1618000008
#                 ],
#                 [
#                     -1998009.6391000003,
#                     -387808.06819999963
#                 ],
#                 [
#                     -1997775.8926999997,
#                     -387852.09050000086
#                 ],
#                 [
#                     -1997521.2065999992,
#                     -387886.79030000046
#                 ],
#                 [
#                     -1997278.3319000006,
#                     -387905.06379999965
#                 ],
#                 [
#                     -1996927.4023000002,
#                     -387876.07850000076
#                 ],
#                 [
#                     -1996757.7446999997,
#                     -387953.25009999983
#                 ],
#                 [
#                     -1996564.8144000005,
#                     -387997.82579999976
#                 ],
#                 [
#                     -1996384.6684000008,
#                     -387949.97250000015
#                 ],
#                 [
#                     -1996121.1254999992,
#                     -387986.9116999991
#                 ],
#                 [
#                     -1995847.1063,
#                     -388019.1978999991
#                 ],
#                 [
#                     -1995625.8402999993,
#                     -388049.65059999935
#                 ],
#                 [
#                     -1995467.269200001,
#                     -388107.3225999996
#                 ],
#                 [
#                     -1995299.0653000008,
#                     -388177.4293000009
#                 ],
#                 [
#                     -1995111.0277999993,
#                     -388283.0207000002
#                 ],
#                 [
#                     -1994947.6064999998,
#                     -388400.3312999997
#                 ],
#                 [
#                     -1994786.8904999997,
#                     -388582.65809999965
#                 ],
#                 [
#                     -1994684.2532000002,
#                     -388785.93989999965
#                 ],
#                 [
#                     -1994557.322899999,
#                     -389019.2497000005
#                 ],
#                 [
#                     -1994361.8554999996,
#                     -389334.01549999975
#                 ],
#                 [
#                     -1994272.4387999997,
#                     -389513.5627999995
#                 ],
#                 [
#                     -1994081.4247999992,
#                     -389726.9444999993
#                 ],
#                 [
#                     -1993886.2265000008,
#                     -389868.96160000004
#                 ],
#                 [
#                     -1993650.6594999991,
#                     -390068.24530000053
#                 ],
#                 [
#                     -1993593.6740000006,
#                     -390116.4474999998
#                 ],
#                 [
#                     -1993383.6198999994,
#                     -390261.7918999996
#                 ],
#                 [
#                     -1992995.3709999993,
#                     -390338.4604000002
#                 ],
#                 [
#                     -1992979.9048999995,
#                     -390341.5145999994
#                 ],
#                 [
#                     -1992707.1390000004,
#                     -390446.1062000003
#                 ],
#                 [
#                     -1992362.3287000004,
#                     -390443.25210000016
#                 ],
#                 [
#                     -1992056.2865999993,
#                     -390458.99530000053
#                 ],
#                 [
#                     -1991771.4462000001,
#                     -390431.6548999995
#                 ],
#                 [
#                     -1991490.204500001,
#                     -390379.45639999956
#                 ],
#                 [
#                     -1991322.7502999995,
#                     -390342.5918000005
#                 ],
#                 [
#                     -1991321.9806999993,
#                     -390342.4219000004
#                 ],
#                 [
#                     -1991176.6778999995,
#                     -390282.9726
#                 ],
#                 [
#                     -1990918.3180999998,
#                     -390208.1313000005
#                 ],
#                 [
#                     -1990369.3570000008,
#                     -390242.15440000035
#                 ],
#                 [
#                     -1990079.2522999998,
#                     -390419.7332000006
#                 ],
#                 [
#                     -1989752.8994999994,
#                     -390723.3989000004
#                 ],
#                 [
#                     -1989393.0162000004,
#                     -391017.5684999991
#                 ],
#                 [
#                     -1989169.0726999994,
#                     -391197.06149999984
#                 ],
#                 [
#                     -1988945.8412999995,
#                     -391366.4180999994
#                 ],
#                 [
#                     -1988781.6440999992,
#                     -391480.4090999998
#                 ],
#                 [
#                     -1988478.5176999997,
#                     -391709.5184000004
#                 ],
#                 [
#                     -1988348.9754000008,
#                     -391784.4466999993
#                 ],
#                 [
#                     -1988092.8894999996,
#                     -391933.64389999956
#                 ],
#                 [
#                     -1987986.5233999994,
#                     -392027.3763999995
#                 ],
#                 [
#                     -1987633.6675000004,
#                     -392043.6425000001
#                 ],
#                 [
#                     -1987444.0252999999,
#                     -392021.9411999993
#                 ],
#                 [
#                     -1987211.0682999995,
#                     -391868.49310000055
#                 ],
#                 [
#                     -1986955.3275000006,
#                     -391738.0248000007
#                 ],
#                 [
#                     -1986823.1257000007,
#                     -391747.97030000016
#                 ],
#                 [
#                     -1986683.0289999992,
#                     -391804.47360000014
#                 ],
#                 [
#                     -1986591.0269000009,
#                     -391932.7923000008
#                 ],
#                 [
#                     -1986508.3619,
#                     -392128.10199999996
#                 ],
#                 [
#                     -1986287.5905000009,
#                     -392334.69710000046
#                 ],
#                 [
#                     -1986167.8990000002,
#                     -392438.4553999994
#                 ],
#                 [
#                     -1986016.2846000008,
#                     -392539.40410000086
#                 ],
#                 [
#                     -1985753.5607999992,
#                     -392593.1973000001
#                 ],
#                 [
#                     -1985560.6698000003,
#                     -392638.0554000009
#                 ],
#                 [
#                     -1985426.1314000003,
#                     -392745.1405999996
#                 ],
#                 [
#                     -1985380.1917000003,
#                     -392869.87519999966
#                 ],
#                 [
#                     -1985373.4177,
#                     -393081.90589999966
#                 ],
#                 [
#                     -1985371.7810999993,
#                     -393275.81409999914
#                 ],
#                 [
#                     -1985354.2346,
#                     -393428.41559999995
#                 ],
#                 [
#                     -1985243.8895999994,
#                     -393706.0733000003
#                 ],
#                 [
#                     -1985129.0078999996,
#                     -393964.21660000086
#                 ],
#                 [
#                     -1984933.4162000008,
#                     -394171.6150000002
#                 ],
#                 [
#                     -1984787.7281999998,
#                     -394271.22030000016
#                 ],
#                 [
#                     -1984353.1304000001,
#                     -394513.37289999984
#                 ],
#                 [
#                     -1984010.3500999995,
#                     -394706.83589999937
#                 ],
#                 [
#                     -1983655.5494,
#                     -394875.45529999956
#                 ],
#                 [
#                     -1983390.898,
#                     -394974.7785
#                 ],
#                 [
#                     -1983199.7545999996,
#                     -395053.80780000053
#                 ],
#                 [
#                     -1982968.3084999993,
#                     -395228.2361999992
#                 ],
#                 [
#                     -1982712.4332999997,
#                     -395525.8326999992
#                 ],
#                 [
#                     -1982574.2672000006,
#                     -395644.25659999996
#                 ],
#                 [
#                     -1982452.1565000005,
#                     -395831.43989999965
#                 ],
#                 [
#                     -1982347.6702999994,
#                     -395986.83210000023
#                 ],
#                 [
#                     -1982220.0143,
#                     -396123.4450000003
#                 ],
#                 [
#                     -1982110.5776000004,
#                     -396204.11390000023
#                 ],
#                 [
#                     -1982002.091,
#                     -396208.48230000027
#                 ],
#                 [
#                     -1981870.2146000005,
#                     -396152.77710000053
#                 ],
#                 [
#                     -1981771.659,
#                     -395971.9397999998
#                 ],
#                 [
#                     -1981752.3413999993,
#                     -395755.23790000007
#                 ],
#                 [
#                     -1981713.9871999994,
#                     -395456.9545000009
#                 ],
#                 [
#                     -1981670.3303999994,
#                     -395149.3540000003
#                 ],
#                 [
#                     -1981553.3135000002,
#                     -394768.8847000003
#                 ],
#                 [
#                     -1981426.3583000004,
#                     -394452.9763999991
#                 ],
#                 [
#                     -1981244.7676999997,
#                     -394305.04759999923
#                 ],
#                 [
#                     -1981099.4087000005,
#                     -394231.82740000077
#                 ],
#                 [
#                     -1980975.3562000003,
#                     -394236.4462000001
#                 ],
#                 [
#                     -1980899.2969000004,
#                     -394312.61810000055
#                 ],
#                 [
#                     -1980835.4765000008,
#                     -394441.37450000085
#                 ],
#                 [
#                     -1980833.3069000002,
#                     -394486.6732999999
#                 ],
#                 [
#                     -1980833.2414999995,
#                     -394488.0175999999
#                 ],
#                 [
#                     -1980825.7024000008,
#                     -394640.5895000007
#                 ],
#                 [
#                     -1980757.2877999991,
#                     -394856.74569999985
#                 ],
#                 [
#                     -1980716.7271999996,
#                     -395125.18090000004
#                 ],
#                 [
#                     -1980711.3259999994,
#                     -395437.0611000005
#                 ],
#                 [
#                     -1980711.4968999997,
#                     -395438.0295000002
#                 ],
#                 [
#                     -1980759.2214000002,
#                     -395709.1612999998
#                 ],
#                 [
#                     -1980759.466,
#                     -395710.03309999965
#                 ],
#                 [
#                     -1980834.6000999995,
#                     -395978.3356999997
#                 ],
#                 [
#                     -1980834.8716000002,
#                     -395979.27610000037
#                 ],
#                 [
#                     -1980917.5381000005,
#                     -396266.61539999954
#                 ],
#                 [
#                     -1980917.5382000003,
#                     -396266.69150000066
#                 ],
#                 [
#                     -1980925.448999999,
#                     -396447.8355999999
#                 ],
#                 [
#                     -1980887.382099999,
#                     -396646.6121999994
#                 ],
#                 [
#                     -1980799.8717,
#                     -396794.43909999914
#                 ],
#                 [
#                     -1980627.3582000006,
#                     -396886.2993999999
#                 ],
#                 [
#                     -1980412.7499000002,
#                     -396905.05509999953
#                 ],
#                 [
#                     -1980225.0417999998,
#                     -396895.0485999994
#                 ],
#                 [
#                     -1980073.7288000006,
#                     -396886.9036999997
#                 ],
#                 [
#                     -1979796.2566999998,
#                     -396837.4008000009
#                 ],
#                 [
#                     -1979425.1056999993,
#                     -396681.5560999997
#                 ],
#                 [
#                     -1979175.1872000005,
#                     -396642.8719999995
#                 ],
#                 [
#                     -1979052.5395,
#                     -396640.1568999998
#                 ],
#                 [
#                     -1978844.2617000006,
#                     -396605.6495999992
#                 ],
#                 [
#                     -1978660.6579999998,
#                     -396596.34050000086
#                 ],
#                 [
#                     -1978502.5274999999,
#                     -396615.9065000005
#                 ],
#                 [
#                     -1978179.8827999998,
#                     -396708.00689999945
#                 ],
#                 [
#                     -1978034.6984,
#                     -396782.90059999935
#                 ],
#                 [
#                     -1977723.4593000002,
#                     -396910.4936999995
#                 ],
#                 [
#                     -1977486.8716000002,
#                     -396982.47089999914
#                 ],
#                 [
#                     -1977362.0810000002,
#                     -397104.6405999996
#                 ],
#                 [
#                     -1977258.1151,
#                     -397222.1793000009
#                 ],
#                 [
#                     -1977060.9659000002,
#                     -397302.27710000053
#                 ],
#                 [
#                     -1976905.5592999998,
#                     -397400.58809999935
#                 ],
#                 [
#                     -1976768.5141000003,
#                     -397470.19129999913
#                 ],
#                 [
#                     -1976641.6009,
#                     -397489.4883999992
#                 ],
#                 [
#                     -1976511.0711000003,
#                     -397412.67310000025
#                 ],
#                 [
#                     -1976294.8213999998,
#                     -397303.8629999999
#                 ],
#                 [
#                     -1976071.8329000007,
#                     -397179.5088999998
#                 ],
#                 [
#                     -1975819.0870999992,
#                     -397048.0985000003
#                 ],
#                 [
#                     -1975558.6773000006,
#                     -397004.75579999946
#                 ],
#                 [
#                     -1975295.0344999991,
#                     -397027.9989
#                 ],
#                 [
#                     -1975195.637599999,
#                     -397057.8643999994
#                 ],
#                 [
#                     -1975099.9028999992,
#                     -397183.79649999924
#                 ],
#                 [
#                     -1975039.1579,
#                     -397325.64079999924
#                 ],
#                 [
#                     -1975003.4306000005,
#                     -397547.9473000001
#                 ],
#                 [
#                     -1975011.8540000003,
#                     -397811.9134999998
#                 ],
#                 [
#                     -1975031.3841999993,
#                     -398069.88049999997
#                 ],
#                 [
#                     -1975035.9661999997,
#                     -398196.7898999993
#                 ],
#                 [
#                     -1975014.8910000008,
#                     -398387.9877000004
#                 ],
#                 [
#                     -1974975.5950000007,
#                     -398514.48310000077
#                 ],
#                 [
#                     -1974922.0935999993,
#                     -398639.0265999995
#                 ],
#                 [
#                     -1974922.3791000005,
#                     -398639.56159999967
#                 ],
#                 [
#                     -1974991.3673,
#                     -398769.7804000005
#                 ],
#                 [
#                     -1975044.1478000004,
#                     -398996.0008000005
#                 ],
#                 [
#                     -1975044.1230999995,
#                     -398996.3987000007
#                 ],
#                 [
#                     -1975026.0074000005,
#                     -399293.7000999991
#                 ],
#                 [
#                     -1974990.7634999994,
#                     -399585.0105000008
#                 ],
#                 [
#                     -1974929.8995999992,
#                     -399820.2133000009
#                 ],
#                 [
#                     -1974821.6690999996,
#                     -400201.0445000008
#                 ],
#                 [
#                     -1974816.3455999997,
#                     -400239.0259000007
#                 ],
#                 [
#                     -1974767.670499999,
#                     -400586.3937999997
#                 ],
#                 [
#                     -1974714.6169000007,
#                     -400881.9528000001
#                 ],
#                 [
#                     -1974714.6541000009,
#                     -400882.85789999925
#                 ],
#                 [
#                     -1974724.5263,
#                     -401119.06829999946
#                 ],
#                 [
#                     -1974726.9090999998,
#                     -401176.0834999997
#                 ],
#                 [
#                     -1974726.9598999992,
#                     -401176.1687000003
#                 ],
#                 [
#                     -1974799.9473,
#                     -401328.08960000053
#                 ],
#                 [
#                     -1974932.1882000007,
#                     -401546.18930000067
#                 ],
#                 [
#                     -1975071.6199999992,
#                     -401728.1071000006
#                 ],
#                 [
#                     -1975384.8004,
#                     -401783.0722000003
#                 ],
#                 [
#                     -1975584.4192999993,
#                     -401740.1727000009
#                 ],
#                 [
#                     -1975786.7493999992,
#                     -401655.3507000003
#                 ],
#                 [
#                     -1975923.6162,
#                     -401557.9855000004
#                 ],
#                 [
#                     -1975924.3605000004,
#                     -401557.9439000003
#                 ],
#                 [
#                     -1976065.5347000007,
#                     -401549.3602000009
#                 ],
#                 [
#                     -1976179.4134999998,
#                     -401581.5769999996
#                 ],
#                 [
#                     -1976318.4869999997,
#                     -401601.09640000015
#                 ],
#                 [
#                     -1976500.6261999998,
#                     -401724.5865000002
#                 ],
#                 [
#                     -1976672.4154000003,
#                     -401857.43569999933
#                 ],
#                 [
#                     -1976794.9211999997,
#                     -401953.2690999992
#                 ],
#                 [
#                     -1977035.6384999994,
#                     -402166.99200000055
#                 ],
#                 [
#                     -1977129.5439,
#                     -402328.0700000003
#                 ],
#                 [
#                     -1977192.1067999993,
#                     -402462.19370000064
#                 ],
#                 [
#                     -1977259.7795000002,
#                     -402698.54089999944
#                 ],
#                 [
#                     -1977465.5319999997,
#                     -403137.61659999937
#                 ],
#                 [
#                     -1977588.9410999995,
#                     -403371.43280000053
#                 ],
#                 [
#                     -1977641.4816999994,
#                     -403569.85160000063
#                 ],
#                 [
#                     -1977641.5173000004,
#                     -403570.33210000023
#                 ],
#                 [
#                     -1977641.5288999993,
#                     -403570.6442000009
#                 ],
#                 [
#                     -1977657.7170000002,
#                     -403894.08779999986
#                 ],
#                 [
#                     -1977657.7972,
#                     -403894.3610999994
#                 ],
#                 [
#                     -1977748.2897999994,
#                     -404215.16640000045
#                 ],
#                 [
#                     -1977870.6011999995,
#                     -404404.15190000087
#                 ],
#                 [
#                     -1978045.2953999992,
#                     -404522.5471999999
#                 ],
#                 [
#                     -1978198.7906,
#                     -404590.38910000026
#                 ],
#                 [
#                     -1978513.1837000009,
#                     -404583.2759000007
#                 ],
#                 [
#                     -1978686.5874000005,
#                     -404508.47470000014
#                 ],
#                 [
#                     -1978846.9973000009,
#                     -404378.0387999993
#                 ],
#                 [
#                     -1978993.9517,
#                     -404230.0971000008
#                 ],
#                 [
#                     -1979154.2946000006,
#                     -404085.9187000003
#                 ],
#                 [
#                     -1979367.6293000001,
#                     -403873.95109999925
#                 ],
#                 [
#                     -1979555.3507000003,
#                     -403820.2416999992
#                 ],
#                 [
#                     -1979711.9899000004,
#                     -403794.2619000003
#                 ],
#                 [
#                     -1979913.1697000004,
#                     -403758.03810000047
#                 ],
#                 [
#                     -1980110.8341000006,
#                     -403760.3775999993
#                 ],
#                 [
#                     -1980358.426000001,
#                     -403775.5175999999
#                 ],
#                 [
#                     -1980527.2102000006,
#                     -403788.1199999992
#                 ],
#                 [
#                     -1980759.5112999994,
#                     -403845.0376999993
#                 ],
#                 [
#                     -1980898.0821000002,
#                     -403902.4489999991
#                 ],
#                 [
#                     -1981008.9392000008,
#                     -403918.33290000074
#                 ],
#                 [
#                     -1981145.9590000007,
#                     -403959.09249999933
#                 ],
#                 [
#                     -1981268.7996999994,
#                     -403989.28639999963
#                 ],
#                 [
#                     -1981454.3210000005,
#                     -404060.1969000008
#                 ],
#                 [
#                     -1981652.3713000007,
#                     -404117.7541000005
#                 ],
#                 [
#                     -1981882.3264000006,
#                     -404164.6779999994
#                 ],
#                 [
#                     -1982110.8538000006,
#                     -404218.6194000002
#                 ],
#                 [
#                     -1982229.2796999998,
#                     -404256.8378999997
#                 ],
#                 [
#                     -1982259.0698000006,
#                     -404384.52329999954
#                 ],
#                 [
#                     -1982236.7537999991,
#                     -404489.9219000004
#                 ],
#                 [
#                     -1982152.4398999996,
#                     -404557.67229999974
#                 ],
#                 [
#                     -1982037.5899999999,
#                     -404601.8055000007
#                 ],
#                 [
#                     -1981910.8720999993,
#                     -404662.0879999995
#                 ],
#                 [
#                     -1981798.632099999,
#                     -404771.1911999993
#                 ],
#                 [
#                     -1981698.4901,
#                     -404918.5814999994
#                 ],
#                 [
#                     -1981633.0302000009,
#                     -405134.05700000003
#                 ],
#                 [
#                     -1981580.1258000005,
#                     -405457.0462999996
#                 ],
#                 [
#                     -1981573.9995000008,
#                     -405765.7937000003
#                 ],
#                 [
#                     -1981541.3824000005,
#                     -406014.8783999998
#                 ],
#                 [
#                     -1981577.8390999995,
#                     -406130.83029999956
#                 ],
#                 [
#                     -1981691.0253999997,
#                     -406280.5778999999
#                 ],
#                 [
#                     -1981819.6861000005,
#                     -406402.8161999993
#                 ],
#                 [
#                     -1982044.4290999994,
#                     -406561.24709999934
#                 ],
#                 [
#                     -1982355.8564999998,
#                     -406796.2692000009
#                 ],
#                 [
#                     -1982676.0219999999,
#                     -406988.09600000083
#                 ],
#                 [
#                     -1982922.2860000003,
#                     -407144.9138999991
#                 ],
#                 [
#                     -1983124.927100001,
#                     -407329.36759999953
#                 ],
#                 [
#                     -1983241.8772,
#                     -407481.7564000003
#                 ],
#                 [
#                     -1983323.6012999993,
#                     -407590.4933000002
#                 ],
#                 [
#                     -1983539.4439000003,
#                     -407751.1735999994
#                 ],
#                 [
#                     -1983674.0037999991,
#                     -407871.8443
#                 ],
#                 [
#                     -1983773.2558999993,
#                     -408042.23330000043
#                 ],
#                 [
#                     -1983813.5614999998,
#                     -408188.04030000046
#                 ],
#                 [
#                     -1983832.382099999,
#                     -408335.74430000037
#                 ],
#                 [
#                     -1983800.0431999993,
#                     -408505.44030000083
#                 ],
#                 [
#                     -1983746.7750000004,
#                     -408652.56870000064
#                 ],
#                 [
#                     -1983750.5201999992,
#                     -408775.86759999953
#                 ],
#                 [
#                     -1983763.1060000006,
#                     -408883.4124999996
#                 ],
#                 [
#                     -1983766.8564,
#                     -408911.3372000009
#                 ],
#                 [
#                     -1983784.216,
#                     -409040.84259999916
#                 ],
#                 [
#                     -1983810.4978,
#                     -409193.59970000014
#                 ],
#                 [
#                     -1983849.6689,
#                     -409388.24420000054
#                 ],
#                 [
#                     -1983849.6986999996,
#                     -409388.4754000008
#                 ],
#                 [
#                     -1983858.4207000006,
#                     -409479.38120000064
#                 ],
#                 [
#                     -1983858.517000001,
#                     -409479.9438000005
#                 ],
#                 [
#                     -1983873.9024999999,
#                     -409572.4991999995
#                 ],
#                 [
#                     -1983893.4421999995,
#                     -409723.26659999974
#                 ],
#                 [
#                     -1983943.9287,
#                     -409939.4079
#                 ],
#                 [
#                     -1983944.0141000003,
#                     -409939.6252999995
#                 ],
#                 [
#                     -1983944.1203000005,
#                     -409939.9241000004
#                 ],
#                 [
#                     -1984027.0266999993,
#                     -410147.9184000008
#                 ],
#                 [
#                     -1984078.9430999998,
#                     -410245.84520000033
#                 ],
#                 [
#                     -1984105.2683000006,
#                     -410295.49620000087
#                 ],
#                 [
#                     -1984185.788899999,
#                     -410439.3487999998
#                 ],
#                 [
#                     -1984198.0932,
#                     -410456.2718000002
#                 ],
#                 [
#                     -1984240.8248999994,
#                     -410515.49259999953
#                 ],
#                 [
#                     -1984241.1752000004,
#                     -410515.9782999996
#                 ],
#                 [
#                     -1984269.0160000008,
#                     -410554.48790000007
#                 ],
#                 [
#                     -1984275.3960999995,
#                     -410562.42339999974
#                 ],
#                 [
#                     -1984343.9695999995,
#                     -410647.75210000016
#                 ],
#                 [
#                     -1984466.6446000002,
#                     -410771.05120000057
#                 ],
#                 [
#                     -1984584.9091999996,
#                     -410888.8830999993
#                 ],
#                 [
#                     -1984667.3576999996,
#                     -411000.68930000067
#                 ],
#                 [
#                     -1984682.8244000003,
#                     -411019.6066999994
#                 ],
#                 [
#                     -1984683.1254999992,
#                     -411019.97440000065
#                 ],
#                 [
#                     -1984746.0580000002,
#                     -411096.6115000006
#                 ],
#                 [
#                     -1984812.6601999998,
#                     -411167.46389999986
#                 ],
#                 [
#                     -1984908.4836,
#                     -411269.53839999996
#                 ],
#                 [
#                     -1985039.2817000002,
#                     -411387.5047999993
#                 ],
#                 [
#                     -1985158.2829,
#                     -411457.9615000002
#                 ],
#                 [
#                     -1985158.8136,
#                     -411458.2694000006
#                 ],
#                 [
#                     -1985202.7504999992,
#                     -411484.3929999992
#                 ],
#                 [
#                     -1985289.698999999,
#                     -411497.0616999995
#                 ],
#                 [
#                     -1985348.5390000008,
#                     -411505.6392000001
#                 ],
#                 [
#                     -1985581.866800001,
#                     -411496.14360000007
#                 ],
#                 [
#                     -1985582.1007000003,
#                     -411496.13800000027
#                 ],
#                 [
#                     -1985584.0973000005,
#                     -411495.9671
#                 ],
#                 [
#                     -1985749.1223000009,
#                     -411492.38350000046
#                 ],
#                 [
#                     -1985829.6937000006,
#                     -411482.65210000053
#                 ],
#                 [
#                     -1985830.1225000005,
#                     -411482.6059000008
#                 ],
#                 [
#                     -1985870.8911000006,
#                     -411477.7281999998
#                 ],
#                 [
#                     -1985977.1194000002,
#                     -411463.5987999998
#                 ],
#                 [
#                     -1985977.6775000002,
#                     -411463.59479999915
#                 ],
#                 [
#                     -1986042.5061000008,
#                     -411462.17650000006
#                 ],
#                 [
#                     -1986164.3277000003,
#                     -411447.7673000004
#                 ],
#                 [
#                     -1986220.9386,
#                     -411434.55140000023
#                 ],
#                 [
#                     -1986270.5318,
#                     -411423.1486000009
#                 ],
#                 [
#                     -1986270.6503999997,
#                     -411423.11759999953
#                 ],
#                 [
#                     -1986351.3813000005,
#                     -411404.4480000008
#                 ],
#                 [
#                     -1986437.740700001,
#                     -411369.20680000074
#                 ],
#                 [
#                     -1986437.9081999995,
#                     -411369.13079999946
#                 ],
#                 [
#                     -1986565.5910999998,
#                     -411316.7404999994
#                 ],
#                 [
#                     -1986788.2776999995,
#                     -411265.1372999996
#                 ],
#                 [
#                     -1986958.4546000008,
#                     -411201.0499000009
#                 ],
#                 [
#                     -1987027.0560999997,
#                     -411175.3956000004
#                 ],
#                 [
#                     -1987178.7705000006,
#                     -411089.29560000077
#                 ],
#                 [
#                     -1987298.9823000003,
#                     -411039.9254999999
#                 ],
#                 [
#                     -1987386.6132999994,
#                     -411026.4558000006
#                 ],
#                 [
#                     -1987406.5902999993,
#                     -411027.11539999954
#                 ],
#                 [
#                     -1987406.7171,
#                     -411027.11539999954
#                 ],
#                 [
#                     -1987407.1202000007,
#                     -411027.11920000054
#                 ],
#                 [
#                     -1987425.0362,
#                     -411027.5518999994
#                 ],
#                 [
#                     -1987465.3805999998,
#                     -411028.7570999991
#                 ],
#                 [
#                     -1987639.5930000003,
#                     -410957.3016999997
# ...
#                     -384959.4812000003
#                 ],
#                 [
#                     -2025272.8728,
#                     -384858.9232999999
#                 ],
#                 [
#                     -2025247.7710999995,
#                     -384778.4475999996
#                 ],
#                 [
#                     -2025296.8067000005,
#                     -384680.61370000057
#                 ],
#                 [
#                     -2025428.2401,
#                     -384560.48420000076
#                 ],
#                 [
#                     -2025576.1384999994,
#                     -384457.20940000005
#                 ],
#                 [
#                     -2025748.0886000004,
#                     -384389.80399999954
#                 ],
#                 [
#                     -2025892.3244000003,
#                     -384297.6062000003
#                 ],
#                 [
#                     -2025990.2602999993,
#                     -384274.85979999974
#                 ],
#                 [
#                     -2026146.4923,
#                     -384193.7128999997
#                 ],
#                 [
#                     -2026277.2400000002,
#                     -384083.9968999997
#                 ],
#                 [
#                     -2026376.1027000006,
#                     -383985.2050000001
#                 ],
#                 [
#                     -2026448.7267000005,
#                     -383854.5376999993
#                 ],
#                 [
#                     -2026471.4277,
#                     -383711.0505999997
#                 ],
#                 [
#                     -2026399.1689999998,
#                     -383589.6453000009
#                 ],
#                 [
#                     -2026253.0555000007,
#                     -383433.5052000005
#                 ],
#                 [
#                     -2026103.7508000005,
#                     -383343.95040000044
#                 ],
#                 [
#                     -2025934.9396000002,
#                     -383237.9587999992
#                 ],
#                 [
#                     -2025746.9963000007,
#                     -383157.0212999992
#                 ],
#                 [
#                     -2025436.7885999996,
#                     -383021.7605000008
#                 ],
#                 [
#                     -2025213.7642,
#                     -382911.19480000064
#                 ],
#                 [
#                     -2025064.3190000001,
#                     -382807.5976
#                 ],
#                 [
#                     -2024972.0908000004,
#                     -382707.9143000003
#                 ],
#                 [
#                     -2024880.6841000002,
#                     -382411.38159999996
#                 ],
#                 [
#                     -2024841.6745999996,
#                     -382164.8813000005
#                 ],
#                 [
#                     -2024825.1667999998,
#                     -382040.94659999944
#                 ],
#                 [
#                     -2024853.8826000001,
#                     -381803.02050000057
#                 ],
#                 [
#                     -2024882.5368000008,
#                     -381564.81629999913
#                 ],
#                 [
#                     -2024892.2435999997,
#                     -381272.5666000005
#                 ],
#                 [
#                     -2024874.7607000005,
#                     -381024.49450000003
#                 ],
#                 [
#                     -2024783.2355000004,
#                     -380807.55790000036
#                 ],
#                 [
#                     -2024685.007099999,
#                     -380695.4605999999
#                 ],
#                 [
#                     -2024552.7800999992,
#                     -380612.00009999983
#                 ],
#                 [
#                     -2024269.6037000008,
#                     -380605.2945000008
#                 ],
#                 [
#                     -2024076.1524999999,
#                     -380674.2982999999
#                 ],
#                 [
#                     -2023790.7164999992,
#                     -380778.17899999954
#                 ],
#                 [
#                     -2023549.2850000001,
#                     -380789.3668000009
#                 ],
#                 [
#                     -2023193.2608000003,
#                     -380792.19370000064
#                 ],
#                 [
#                     -2022945.6791999992,
#                     -380777.23980000056
#                 ],
#                 [
#                     -2022745.8428000007,
#                     -380792.32740000077
#                 ],
#                 [
#                     -2022651.8515000008,
#                     -380759.4331
#                 ],
#                 [
#                     -2022628.9443999995,
#                     -380760.7851999998
#                 ],
#                 [
#                     -2022415.6970000006,
#                     -380772.1384999994
#                 ],
#                 [
#                     -2022268.5355999991,
#                     -380771.6610000003
#                 ],
#                 [
#                     -2022061.2411000002,
#                     -380781.6777999997
#                 ],
#                 [
#                     -2021941.0207000002,
#                     -380776.21350000054
#                 ],
#                 [
#                     -2021642.5010000002,
#                     -380883.01820000075
#                 ],
#                 [
#                     -2021495.1806000005,
#                     -380925.66699999943
#                 ],
#                 [
#                     -2021077.2861000001,
#                     -381046.6478000004
#                 ],
#                 [
#                     -2020493.9412999991,
#                     -381078.02979999967
#                 ],
#                 [
#                     -2020119.523600001,
#                     -381098.53240000084
#                 ],
#                 [
#                     -2019352.4926999994,
#                     -381082.3016999997
#                 ],
#                 [
#                     -2018670.8220000006,
#                     -380970.05790000036
#                 ],
#                 [
#                     -2018583.6572999991,
#                     -380926.1723999996
#                 ],
#                 [
#                     -2018350.5265999995,
#                     -380808.9363000002
#                 ],
#                 [
#                     -2017993.7469999995,
#                     -380608.21839999966
#                 ],
#                 [
#                     -2017840.6786000002,
#                     -380408.8456999995
#                 ],
#                 [
#                     -2017518.3153000008,
#                     -380034.4759999998
#                 ],
#                 [
#                     -2017407.7342000008,
#                     -379856.3333999999
#                 ],
#                 [
#                     -2017297.5286999997,
#                     -379626.28839999996
#                 ],
#                 [
#                     -2017162.9068999998,
#                     -379305.3663999997
#                 ],
#                 [
#                     -2017132.8629,
#                     -379251.1121999994
#                 ],
#                 [
#                     -2017054.4200999998,
#                     -379109.4573999997
#                 ],
#                 [
#                     -2016921.1894000005,
#                     -378981.46499999985
#                 ],
#                 [
#                     -2016711.4855000004,
#                     -378967.7399000004
#                 ],
#                 [
#                     -2016474.2917,
#                     -379050.2885999996
#                 ],
#                 [
#                     -2016319.9143000003,
#                     -379179.30900000036
#                 ],
#                 [
#                     -2016053.521400001,
#                     -379431.12519999966
#                 ],
#                 [
#                     -2015951.3841999993,
#                     -379596.2315999996
#                 ],
#                 [
#                     -2015836.5699000005,
#                     -379747.1779999994
#                 ],
#                 [
#                     -2015770.3231000006,
#                     -379819.25909999944
#                 ],
#                 [
#                     -2015699.4507,
#                     -379896.37319999933
#                 ],
#                 [
#                     -2015619.1023999993,
#                     -380087.6138000004
#                 ],
#                 [
#                     -2015480.6538999993,
#                     -380257.88800000027
#                 ],
#                 [
#                     -2015342.4756000005,
#                     -380362.5063000005
#                 ],
#                 [
#                     -2015105.6686000004,
#                     -380500.31039999984
#                 ],
#                 [
#                     -2014958.9133000001,
#                     -380555.0462999996
#                 ],
#                 [
#                     -2014790.6358000003,
#                     -380718.2464000005
#                 ],
#                 [
#                     -2014670.7433000002,
#                     -380780.7302000001
#                 ],
#                 [
#                     -2014598.2904000003,
#                     -380832.0370000005
#                 ],
#                 [
#                     -2014489.5174000002,
#                     -380902.0033999998
#                 ],
#                 [
#                     -2014290.1282000002,
#                     -380972.3468999993
#                 ],
#                 [
#                     -2014135.0583999995,
#                     -381004.9386999998
#                 ],
#                 [
#                     -2014049.3175000008,
#                     -380972.8604000006
#                 ],
#                 [
#                     -2013961.7020999994,
#                     -380879.1616999991
#                 ],
#                 [
#                     -2013879.2649000008,
#                     -380781.0537999999
#                 ],
#                 [
#                     -2013805.8058000002,
#                     -380694.44040000066
#                 ],
#                 [
#                     -2013674.2835000008,
#                     -380600.5617999993
#                 ],
#                 [
#                     -2013530.5494999997,
#                     -380561.26359999925
#                 ],
#                 [
#                     -2013395.0205000006,
#                     -380623.74010000005
#                 ],
#                 [
#                     -2013315.9091999996,
#                     -380686.79560000077
#                 ],
#                 [
#                     -2013211.7217999995,
#                     -380762.7862999998
#                 ],
#                 [
#                     -2013111.3156000003,
#                     -380855.1815000009
#                 ],
#                 [
#                     -2013026.2510000002,
#                     -381012.9243999999
#                 ],
#                 [
#                     -2012922.8465,
#                     -381199.3724000007
#                 ],
#                 [
#                     -2012789.6878999993,
#                     -381285.3308000006
#                 ],
#                 [
#                     -2012693.8231000006,
#                     -381383.73790000007
#                 ],
#                 [
#                     -2012552.0039000008,
#                     -381406.0627999995
#                 ],
#                 [
#                     -2012352.0576000009,
#                     -381500.78309999965
#                 ],
#                 [
#                     -2012207.7989000008,
#                     -381485.9059999995
#                 ],
#                 [
#                     -2011826.5063000005,
#                     -381688.17720000073
#                 ],
#                 [
#                     -2011627.0066,
#                     -381744.7511
#                 ],
#                 [
#                     -2011472.4087000005,
#                     -381739.18459999934
#                 ],
#                 [
#                     -2011346.5009000003,
#                     -381695.90729999915
#                 ],
#                 [
#                     -2011262.5440999996,
#                     -381604.5917000007
#                 ],
#                 [
#                     -2011203.0869999994,
#                     -381497.5719000008
#                 ],
#                 [
#                     -2011126.6627999991,
#                     -381304.7595000006
#                 ],
#                 [
#                     -2011069.3154000007,
#                     -381193.4495000001
#                 ],
#                 [
#                     -2010979.477499999,
#                     -380996.88379999995
#                 ],
#                 [
#                     -2010910.0030000005,
#                     -380847.0440999996
#                 ],
#                 [
#                     -2010826.0293000005,
#                     -380648.87879999913
#                 ],
#                 [
#                     -2010766.7525999993,
#                     -380462.46079999954
#                 ],
#                 [
#                     -2010681.2892000005,
#                     -380364.7675000001
#                 ],
#                 [
#                     -2010560.9440000001,
#                     -380264.8884999994
#                 ],
#                 [
#                     -2010407.9323999994,
#                     -380172.6190000009
#                 ],
#                 [
#                     -2010225.9876000006,
#                     -380090.3072999995
#                 ],
#                 [
#                     -2010067.5448000003,
#                     -380068.3323999997
#                 ],
#                 [
#                     -2009926.9252000004,
#                     -380149.2390999999
#                 ],
#                 [
#                     -2009834.8394000009,
#                     -380263.77270000055
#                 ],
#                 [
#                     -2009745.8575999998,
#                     -380391.40499999933
#                 ],
#                 [
#                     -2009747.6239999998,
#                     -380532.67679999955
#                 ],
#                 [
#                     -2009747.8165000007,
#                     -380760.6827000007
#                 ],
#                 [
#                     -2009759.2588999998,
#                     -380903.0438000001
#                 ],
#                 [
#                     -2009773.6114000008,
#                     -381138.1107999999
#                 ],
#                 [
#                     -2009700.1190000009,
#                     -381251.73509999923
#                 ],
#                 [
#                     -2009660.8058000002,
#                     -381364.4388999995
#                 ],
#                 [
#                     -2009567.3137999997,
#                     -381486.34369999915
#                 ],
#                 [
#                     -2009502.2972999997,
#                     -381542.72100000083
#                 ],
#                 [
#                     -2009299.3673999999,
#                     -381638.1146000009
#                 ],
#                 [
#                     -2009071.1525999997,
#                     -381732.4474999998
#                 ],
#                 [
#                     -2008727.3680000007,
#                     -381867.5178999994
#                 ],
#                 [
#                     -2008462.2127,
#                     -381991.18569999933
#                 ],
#                 [
#                     -2008268.2365000006,
#                     -382098.0647999998
#                 ],
#                 [
#                     -2008144.9833000004,
#                     -382213.11930000037
#                 ],
#                 [
#                     -2008021.9230000004,
#                     -382355.6473999992
#                 ],
#                 [
#                     -2007961.1658999994,
#                     -382483.7109999992
#                 ],
#                 [
#                     -2007910.3699999992,
#                     -382654.3025000002
#                 ]
#             ]
#         ]
#     }
# }

# %%
# Every feature has a 'geometry' which specifies geo coordinates that make up each geographic thing
# In the case of the wildfire data, most wildfires are bounded shapes, circles, squares, etc. This is
# represented by shapes called 'rings' in GeoJSON.

# Get the geometry for the feature we pulled from the feature_list
gj_geometry = gj_feature['geometry']
# The largest shape (ring) is supposed to be item zero in the list of 'rings'
gj_bigest_ring = gj_geometry['rings'][0]

print(f"The largest ring of gj_feature['features'][{SLOT}]['rings'] consists of {len(gj_bigest_ring)} points.")
# Out:
# The largest ring of gj_feature['features'][0]['rings'] consists of 1132 points.

# %% [markdown]
# # Step 2 - Pulling Wildfire Data

# %% [markdown]
# ## Getting Distance information

# %% [markdown]
# Once you are able to read the wildfire data, you need to be able to find all of the fires within a specified distance from your city. This is a geodetic distance computation. If you are a GIS wizard, you'll know how to do this in your sleep. However, for most of us, who have never done this before, an example is really helpful.

# %%
# helper function
def convert_ring_to_epsg4326(ring_data=None):
    """
    Converts a list of coordinates from a specified coordinate system (ESRI:102008) to EPSG:4326 (WGS84).

    Parameters:
        ring_data (list): List of coordinate pairs in the original coordinate system.

    Returns:
        list: List of coordinate pairs in EPSG:4326 (WGS84).
    """
    
    # Initialize an empty list to store the converted coordinates
    converted_ring = list()
    
    # Create a Transformer from ESRI:102008 to EPSG:4326
    to_epsg4326 = Transformer.from_crs("ESRI:102008", "EPSG:4326")
    
    # Iterate through each coordinate in the input ring_data
    for coord in ring_data:
        # Transform the coordinate to EPSG:4326
        lat, lon = to_epsg4326.transform(coord[0], coord[1])
        new_coord = lat, lon
        # Append the transformed coordinate to the converted_ring list
        converted_ring.append(new_coord)
    
    # Return the list of converted coordinates
    return converted_ring

# %%
# helper function
def shortest_distance_from_place_to_fire_perimeter(place=None, ring_data=None):
    """
    Calculates the shortest distance from a specified place to a fire perimeter defined by a ring of coordinates.

    Parameters:
        place (tuple): A tuple representing the (latitude, longitude) of the specified place.
        ring_data (list): List of coordinate pairs defining the fire perimeter.

    Returns:
        list or None: A list containing the shortest distance in miles and the corresponding coordinate.
                      Returns None if the input data is invalid or empty.
    """
    
    # Convert the ring coordinates to EPSG:4326 (WGS84)
    ring = convert_ring_to_epsg4326(ring_data)
    
    # Create a Geod object for geodetic calculations
    geodcalc = Geod(ellps='WGS84')
    
    # Initialize a list to store the closest point and distance
    closest_point = list()

    # Iterate through each point in the ring
    for point in ring:
        # Calculate the geodetic distance between the specified place and the current point in the ring
        d = geodcalc.inv(place[1], place[0], point[1], point[0])
        
        # Convert the distance to miles
        distance_in_miles = d[2] * 0.00062137
        
        # Check if closest_point is empty or if the current distance is shorter than the stored distance
        if not closest_point or closest_point[0] > distance_in_miles:
            # Update closest_point with the current distance and point
            closest_point = [distance_in_miles, point]

    # Return the closest_point list, or None if no valid data is available
    return closest_point if closest_point else None

# %%
def process_wf_feature(wf_feature, city_latlon):
    """
    Process a wildfire feature and calculate the shortest distance from the specified city.

    Parameters:
        wf_feature (dict): Wildfire feature with geometry and attributes.
        city_latlon (tuple): Tuple representing the (latitude, longitude) of the city.

    Returns:
        tuple or None: A tuple containing the OBJECTID and the shortest distance from the city.
                      Returns None if the input data is invalid or if the feature has an irregular shape.
    """
    try:
        # Extract ring data from the wildfire feature
        ring_data = wf_feature['geometry']['rings'][0]
        
        # Calculate the shortest distance from the city to the fire perimeter
        distance = shortest_distance_from_place_to_fire_perimeter(city_latlon, ring_data)
        
        # Return OBJECTID and the rounded shortest distance
        return wf_feature['attributes']['OBJECTID'], round(distance[0], 2)
    except KeyError:
        # Handle the case where the feature has an irregular shape
        print("{0} fire has an irregular shape; skipping.".format(wf_feature['attributes']['OBJECTID']))
    return None

def process_features(feature_list, city_latlon):
    """
    Process a list of wildfire features and create a DataFrame with OBJECTID and shortest distances.

    Parameters:
        feature_list (list): List of wildfire features.
        city_latlon (tuple): Tuple representing the (latitude, longitude) of the city.

    Returns:
        pd.DataFrame: DataFrame containing OBJECTID and shortest distances.
    """
    fire_ids = []
    shortest_dist_from_edge_list = []

    features_processed = 0
    for wf_feature in feature_list:
        # Process each wildfire feature and obtain the result
        result = process_wf_feature(wf_feature, city_latlon)
        
        # Check if the result is valid
        if result:
            fire_ids.append(result[0])
            shortest_dist_from_edge_list.append(result[1])

        features_processed += 1
        if features_processed % 1000 == 0:
            print("Processed {0} features".format(features_processed))
        if features_processed % 10000 == 0:
            # Create a DataFrame and save it to a CSV file periodically
            dist_df = pd.DataFrame({'OBJECTID': fire_ids, 'shortest_dist': shortest_dist_from_edge_list})
            dist_df.to_csv('distance.csv', index=False)

    # Create the final DataFrame with OBJECTID and shortest distances
    return pd.DataFrame({'OBJECTID': fire_ids, 'shortest_dist': shortest_dist_from_edge_list})

# %%
# Example usage
city_data = CITY_DATA["bismarck"]
# city_data = {'latlon': city_data['latlon']}  # Replace with actual city coordinates
distance_df = process_features(feature_list, city_data['latlon'])
distance_df.to_csv('distance.csv', index=False)
# Out:
# Processed 1000 features
# Processed 2000 features
# Processed 3000 features
# Processed 4000 features
# Processed 5000 features
# Processed 6000 features
# Processed 7000 features
# Processed 8000 features
# Processed 9000 features
# Processed 10000 features
# Processed 11000 features
# Processed 12000 features
# Processed 13000 features
# Processed 14000 features
# Processed 15000 features
# Processed 16000 features
# Processed 17000 features
# Processed 18000 features
# Processed 19000 features
# Processed 20000 features
# Processed 21000 features
# Processed 22000 features
# Processed 23000 features
# Processed 24000 features
# Processed 25000 features
# Processed 26000 features
# Processed 27000 features
# Processed 28000 features
# Processed 29000 features
# Processed 30000 features
# Processed 31000 features
# Processed 32000 features
# Processed 33000 features
# Processed 34000 features
# Processed 35000 features
# Processed 36000 features
# Processed 37000 features
# Processed 38000 features
# Processed 39000 features
# Processed 40000 features
# Processed 41000 features
# Processed 42000 features
# Processed 43000 features
# Processed 44000 features
# Processed 45000 features
# Processed 46000 features
# Processed 47000 features
# Processed 48000 features
# Processed 49000 features
# Processed 50000 features
# Processed 51000 features
# Processed 52000 features
# Processed 53000 features
# Processed 54000 features
# Processed 55000 features
# Processed 56000 features
# Processed 57000 features
# Processed 58000 features
# Processed 59000 features
# Processed 60000 features
# Processed 61000 features
# Processed 62000 features
# Processed 63000 features
# Processed 64000 features
# Processed 65000 features
# Processed 66000 features
# Processed 67000 features
# Processed 68000 features
# Processed 69000 features
# Processed 70000 features
# Processed 71000 features
# Processed 72000 features
# Processed 73000 features
# Processed 74000 features
# Processed 75000 features
# Processed 76000 features
# Processed 77000 features
# Processed 78000 features
# Processed 79000 features
# Processed 80000 features
# Processed 81000 features
# Processed 82000 features
# Processed 83000 features
# Processed 84000 features
# Processed 85000 features
# Processed 86000 features
# Processed 87000 features
# Processed 88000 features
# Processed 89000 features
# Processed 90000 features
# Processed 91000 features
# Processed 92000 features
# Processed 93000 features
# Processed 94000 features
# Processed 95000 features
# Processed 96000 features
# Processed 97000 features
# Processed 98000 features
# Processed 99000 features
# Processed 100000 features
# Processed 101000 features
# Processed 102000 features
# Processed 103000 features
# Processed 104000 features
# Processed 105000 features
# Processed 106000 features
# Processed 107000 features
# Processed 108000 features
# Processed 109000 features
# 109605 fire has an irregular shape; skipping.
# Processed 110000 features
# 110224 fire has an irregular shape; skipping.
# 110639 fire has an irregular shape; skipping.
# Processed 111000 features
# 111431 fire has an irregular shape; skipping.
# 111776 fire has an irregular shape; skipping.
# 111897 fire has an irregular shape; skipping.
# Processed 112000 features
# 112410 fire has an irregular shape; skipping.
# 112415 fire has an irregular shape; skipping.
# Processed 113000 features
# 113411 fire has an irregular shape; skipping.
# 113665 fire has an irregular shape; skipping.
# 113738 fire has an irregular shape; skipping.
# 113766 fire has an irregular shape; skipping.
# 113805 fire has an irregular shape; skipping.
# Processed 114000 features
# 114309 fire has an irregular shape; skipping.
# 114322 fire has an irregular shape; skipping.
# Processed 115000 features
# 115629 fire has an irregular shape; skipping.
# 115974 fire has an irregular shape; skipping.
# Processed 116000 features
# 116235 fire has an irregular shape; skipping.
# Processed 117000 features
# 117086 fire has an irregular shape; skipping.
# Processed 118000 features
# Processed 119000 features
# 119582 fire has an irregular shape; skipping.
# 119617 fire has an irregular shape; skipping.
# 119751 fire has an irregular shape; skipping.
# 119982 fire has an irregular shape; skipping.
# Processed 120000 features
# 120212 fire has an irregular shape; skipping.
# 120431 fire has an irregular shape; skipping.
# 120678 fire has an irregular shape; skipping.
# 120743 fire has an irregular shape; skipping.
# Processed 121000 features
# 121010 fire has an irregular shape; skipping.
# Processed 122000 features
# 122264 fire has an irregular shape; skipping.
# 122531 fire has an irregular shape; skipping.
# Processed 123000 features
# 123761 fire has an irregular shape; skipping.
# Processed 124000 features
# 124535 fire has an irregular shape; skipping.
# Processed 125000 features
# 125046 fire has an irregular shape; skipping.
# 125745 fire has an irregular shape; skipping.
# Processed 126000 features
# Processed 127000 features
# 127492 fire has an irregular shape; skipping.
# Processed 128000 features
# Processed 129000 features
# Processed 130000 features
# Processed 131000 features
# Processed 132000 features
# Processed 133000 features
# Processed 134000 features
# Processed 135000 features

# %% [markdown]
# ## Getting other attributes of the fire

# %% [markdown]
# It seems reasonable that a large fire, that burns a large number of acres, and that is close to a city would put more smoke into a city than a small fire that is much further away. One task is to define your smoke estimate and then apply it to every fire for your city. Should your smoke estimate be cumulative during each year or somehow amortized over the fire season? Document what goes into your decision making and what you did to create your smoke estimate.
#
# **Note** - I have considered the fires that have been burned since 1963

# %%
# Extracting data for Bismarck, North Dakota (Riverside County): Combined dataset (11gb)

filtered_fires = []
feature_count = 0
cnt = 0

wf_reader = WFReader(EXTRACT_FILENAME)
wf_feature = wf_reader.next()

# %%
while wf_feature:
    
    if  wf_feature['attributes']['Fire_Year'] >= 1963:
        if 'rings' in wf_feature['geometry']:
            filtered_fires.append(wf_feature['attributes'])

        
    feature_count += 1
    if feature_count % 1000 == 0:
            print("Processed {0} fires".format(feature_count))
    
    wf_feature = wf_reader.next()
# Out:
# Processed 1000 fires
# Processed 2000 fires
# Processed 3000 fires
# Processed 4000 fires
# Processed 5000 fires
# Processed 6000 fires
# Processed 7000 fires
# Processed 8000 fires
# Processed 9000 fires
# Processed 10000 fires
# Processed 11000 fires
# Processed 12000 fires
# Processed 13000 fires
# Processed 14000 fires
# Processed 15000 fires
# Processed 16000 fires
# Processed 17000 fires
# Processed 18000 fires
# Processed 19000 fires
# Processed 20000 fires
# Processed 21000 fires
# Processed 22000 fires
# Processed 23000 fires
# Processed 24000 fires
# Processed 25000 fires
# Processed 26000 fires
# Processed 27000 fires
# Processed 28000 fires
# Processed 29000 fires
# Processed 30000 fires
# Processed 31000 fires
# Processed 32000 fires
# Processed 33000 fires
# Processed 34000 fires
# Processed 35000 fires
# Processed 36000 fires
# Processed 37000 fires
# Processed 38000 fires
# Processed 39000 fires
# Processed 40000 fires
# Processed 41000 fires
# Processed 42000 fires
# Processed 43000 fires
# Processed 44000 fires
# Processed 45000 fires
# Processed 46000 fires
# Processed 47000 fires
# Processed 48000 fires
# Processed 49000 fires
# Processed 50000 fires
# Processed 51000 fires
# Processed 52000 fires
# Processed 53000 fires
# Processed 54000 fires
# Processed 55000 fires
# Processed 56000 fires
# Processed 57000 fires
# Processed 58000 fires
# Processed 59000 fires
# Processed 60000 fires
# Processed 61000 fires
# Processed 62000 fires
# Processed 63000 fires
# Processed 64000 fires
# Processed 65000 fires
# Processed 66000 fires
# Processed 67000 fires
# Processed 68000 fires
# Processed 69000 fires
# Processed 70000 fires
# Processed 71000 fires
# Processed 72000 fires
# Processed 73000 fires
# Processed 74000 fires
# Processed 75000 fires
# Processed 76000 fires
# Processed 77000 fires
# Processed 78000 fires
# Processed 79000 fires
# Processed 80000 fires
# Processed 81000 fires
# Processed 82000 fires
# Processed 83000 fires
# Processed 84000 fires
# Processed 85000 fires
# Processed 86000 fires
# Processed 87000 fires
# Processed 88000 fires
# Processed 89000 fires
# Processed 90000 fires
# Processed 91000 fires
# Processed 92000 fires
# Processed 93000 fires
# Processed 94000 fires
# Processed 95000 fires
# Processed 96000 fires
# Processed 97000 fires
# Processed 98000 fires
# Processed 99000 fires
# Processed 100000 fires
# Processed 101000 fires
# Processed 102000 fires
# Processed 103000 fires
# Processed 104000 fires
# Processed 105000 fires
# Processed 106000 fires
# Processed 107000 fires
# Processed 108000 fires
# Processed 109000 fires
# Processed 110000 fires
# Processed 111000 fires
# Processed 112000 fires
# Processed 113000 fires
# Processed 114000 fires
# Processed 115000 fires
# Processed 116000 fires
# Processed 117000 fires
# Processed 118000 fires
# Processed 119000 fires
# Processed 120000 fires
# Processed 121000 fires
# Processed 122000 fires
# Processed 123000 fires
# Processed 124000 fires
# Processed 125000 fires
# Processed 126000 fires
# Processed 127000 fires
# Processed 128000 fires
# Processed 129000 fires
# Processed 130000 fires
# Processed 131000 fires
# Processed 132000 fires
# Processed 133000 fires
# Processed 134000 fires
# Processed 135000 fires

# %%
len(filtered_fires)
# Out:
# 117543

# %%
filtered_fires
# Out:
# [{'OBJECTID': 14299,
#   'USGS_Assigned_ID': 14299,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 40992.45827111476,
#   'GIS_Hectares': 16589.05930244248,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_National_BLM_Fire_Perimeters_LADP (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (3)',
#   'Listed_Fire_Names': 'RATTLESNAKE (4)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-06 (3) | Listed Wildfire Controlled Date(s): 1963-12-31 (3)',
#   'Listed_Fire_Causes': 'Unknown (3)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (4)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.38535519109185146,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 73550.42811804128,
#   'Shape_Area': 165890593.0244248},
#  {'OBJECTID': 14300,
#   'USGS_Assigned_ID': 14300,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 25757.09020335899,
#   'GIS_Hectares': 10423.524591179945,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Northern_Rockies_1889_2003 (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1)',
#   'Listed_Fire_Types': 'Wildfire (2), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'McChord Butte (2), No Fire Name Provided (1), Mcchord Butte (1)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-07-28 (1) | Listed Other Fire Date(s): 2019-09-13 - NIFC DATE_CUR field (1), 2019-09-13 - REVDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (1)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.36481483475390875,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 59920.576713408,
#   'Shape_Area': 104235245.91179945},
#  {'OBJECTID': 14301,
#   'USGS_Assigned_ID': 14301,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (5), 3 (15), 5 (1)',
#   'GIS_Acres': 45527.21098592895,
#   'GIS_Hectares': 18424.208617236643,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (5), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (5), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (5), Comb_National_BLM_Fire_Perimeters_LADP (5), Comb_National_LTDL_Project_Wildfire_Polys (1)',
#   'Listed_Fire_Types': 'Wildfire (6), Likely Wildfire (15)',
#   'Listed_Fire_Names': 'WILLOW CREEK (16), EAST CRANE CREEK (4), Crane Creek Fire (1)',
#   'Listed_Fire_Codes': 'No code provided (21)',
#   'Listed_Fire_IDs': '1963-NA-000000 (10)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-06 (15) | Listed Wildfire Controlled Date(s): 1963-12-31 (15)',
#   'Listed_Fire_Causes': 'Unknown (15)',
#   'Listed_Fire_Cause_Class': 'Undetermined (21)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (20)',
#   'Listed_Notes': 'F40/F43 (12)',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.32092727782414426,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 84936.82781032207,
#   'Shape_Area': 184242086.1723664},
#  {'OBJECTID': 14302,
#   'USGS_Assigned_ID': 14302,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3), 5 (1)',
#   'GIS_Acres': 10395.010334268736,
#   'GIS_Hectares': 4206.711433214981,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (1), Comb_National_LTDL_Project_Wildfire_Polys (1)',
#   'Listed_Fire_Types': 'Wildfire (2), Likely Wildfire (3)',
#   'Listed_Fire_Names': 'SOUTH CANYON CREEK (4), No Fire Name Provided (1)',
#   'Listed_Fire_Codes': 'No code provided (5)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-06 (3) | Listed Wildfire Controlled Date(s): 1963-12-31 (3)',
#   'Listed_Fire_Causes': 'Unknown (3)',
#   'Listed_Fire_Cause_Class': 'Undetermined (5)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (4)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.42893577919846543,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 35105.90360242245,
#   'Shape_Area': 42067114.33214981},
#  {'OBJECTID': 14303,
#   'USGS_Assigned_ID': 14303,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 9983.605738356093,
#   'GIS_Hectares': 4040.2219000975856,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (3)',
#   'Listed_Fire_Names': 'WEBB CREEK (4)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-06 (3) | Listed Wildfire Controlled Date(s): 1963-12-31 (3)',
#   'Listed_Fire_Causes': 'Unknown (3)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (4)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.7031775635344893,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 26870.456126106852,
#   'Shape_Area': 40402219.000975855},
#  {'OBJECTID': 14304,
#   'USGS_Assigned_ID': 14304,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2), 5 (1)',
#   'GIS_Acres': 9674.175811826888,
#   'GIS_Hectares': 3915.0000515518386,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_National_LTDL_Project_Wildfire_Polys (1)',
#   'Listed_Fire_Types': 'Wildfire (2), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3), ZZ_Unnamed (1)',
#   'Listed_Fire_Codes': 'No code provided (3), 2331 (1)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (2) | Listed Wildfire Controlled Date(s): 1963-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.09511031166178109,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 71921.2150225822,
#   'Shape_Area': 39150000.51551838},
#  {'OBJECTID': 14305,
#   'USGS_Assigned_ID': 14305,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (3), 3 (3)',
#   'GIS_Acres': 4995.910129347736,
#   'GIS_Hectares': 2021.7730992684105,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (3), Comb_National_USFS_Final_Fire_Perimeter (3)',
#   'Listed_Fire_Types': 'Wildfire (6)',
#   'Listed_Fire_Names': 'No Fire Name Provided (6)',
#   'Listed_Fire_Codes': 'No code provided (6)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Other Fire Date(s): 2018-05-02 - NIFC DATE_CUR field (3), 2018-05-02 - REVDATE field (3)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (6)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized Other (3)',
#   'Listed_Notes': 'Digitized from historic fire atlases (6)',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.9949479983989724,
#   'Circle_Flag': 1,
#   'Exclude_From_Summary_Rasters': 'Yes',
#   'Shape_Length': 15979.785579430853,
#   'Shape_Area': 20217730.992684104},
#  {'OBJECTID': 14306,
#   'USGS_Assigned_ID': 14306,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (1)',
#   'GIS_Acres': 4995.253625665688,
#   'GIS_Hectares': 2021.5074216542077,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1)',
#   'Listed_Fire_Types': 'Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (2)',
#   'Listed_Fire_Codes': 'No code provided (2)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Other Fire Date(s): 2018-05-02 - NIFC DATE_CUR field (1), 2018-05-02 - REVDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (2)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized Other (1)',
#   'Listed_Notes': 'Digitized from historic fire atlases (2)',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': 'Caution, this Wildfire in 1963 overlaps with a Wildfire that occurred in 1964 (1 year difference). The overlapping fire overlaps by 11.9% (592.0 acres). Overlapping fire USGS Assigned ID: 14618.',
#   'Circleness_Scale': 0.9947067163990474,
#   'Circle_Flag': 1,
#   'Exclude_From_Summary_Rasters': 'Yes',
#   'Shape_Length': 15980.673438555406,
#   'Shape_Area': 20215074.216542076},
#  {'OBJECTID': 14307,
#   'USGS_Assigned_ID': 14307,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (2), 3 (3)',
#   'GIS_Acres': 4359.9365769677215,
#   'GIS_Hectares': 1764.4037337758498,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (2), Comb_National_NPS_Wildland_Fire_Perimeters (1), Comb_State_Alaska_Fire_History_Perimeters (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1)',
#   'Listed_Fire_Types': 'Wildfire (4), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'KOBUK 5 (5)',
#   'Listed_Fire_Codes': 'No code provided (4), 56 (1)',
#   'Listed_Fire_IDs': '1963-AKKOY-000056 (1), 1963-AKKOP-2005 (2), 26176 (1)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-06-21 (1) | Listed Wildfire Controlled Date(s): 1963-06-21 (1) | Listed Wildfire Out Date(s): 1963-06-21 (1) | Listed Other Fire Date(s): 1963-11-01 - NIFC DATE_CUR field (1), 2017-03-13 - NIFC DATE_CUR field (1), 1963-11-01 - PERIMETERDATE field (1), 2010-02-04 - DATE_CUR field (1)',
#   'Listed_Fire_Causes': 'Natural (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4), Natural (1)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized (2), Digitized - Image (1)',
#   'Listed_Notes': 'Digitized perimeter from 1985 Landsat image  (P78 R13). (4), Digitized perimeter from 1985 Landsat image  (P78 (1)',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5574368993074131,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 19943.715003203102,
#   'Shape_Area': 17644037.337758496},
#  {'OBJECTID': 14308,
#   'USGS_Assigned_ID': 14308,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 4293.41061336422,
#   'GIS_Hectares': 1737.4816314693317,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_National_BLM_Fire_Perimeters_LADP (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3)',
#   'Listed_Fire_Codes': 'No code provided (3)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (2) | Listed Wildfire Controlled Date(s): 1963-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.3446475926885647,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 25169.664017084466,
#   'Shape_Area': 17374816.314693317},
#  {'OBJECTID': 14309,
#   'USGS_Assigned_ID': 14309,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 3253.602941048139,
#   'GIS_Hectares': 1316.6863957920193,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_State_Alaska_Fire_History_Perimeters (1)',
#   'Listed_Fire_Types': 'Wildfire (2), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'KOLIGANEK (3)',
#   'Listed_Fire_Codes': 'No code provided (2), 80 (1)',
#   'Listed_Fire_IDs': '1963-AKCI-000080 (1), 26175 (1)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Other Fire Date(s): 1963-11-01 - NIFC DATE_CUR field (1), 2008-10-09 - DATE_CUR field (1), 1963-11-02 - PERIMETERDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized (1), Digitized - Image (1)',
#   'Listed_Notes': 'Perimeter modified from 1974 Landsat image P78 R18. (2), Perimeter modified from 1974 Landsat image P78 R18 (1)',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.6382957814002654,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 16100.342660916645,
#   'Shape_Area': 13166863.957920192},
#  {'OBJECTID': 14310,
#   'USGS_Assigned_ID': 14310,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 3071.2087438776393,
#   'GIS_Hectares': 1242.8740829692263,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3)',
#   'Listed_Fire_Codes': 'No code provided (3)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (2) | Listed Wildfire Controlled Date(s): 1963-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5030575994855097,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 17620.151611709753,
#   'Shape_Area': 12428740.829692263},
#  {'OBJECTID': 14311,
#   'USGS_Assigned_ID': 14311,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 3022.2701042653275,
#   'GIS_Hectares': 1223.069318167366,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_National_BLM_Fire_Perimeters_LADP (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3)',
#   'Listed_Fire_Codes': 'No code provided (3)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (2) | Listed Wildfire Controlled Date(s): 1963-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5689501151390935,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 16435.895562895297,
#   'Shape_Area': 12230693.181673659},
#  {'OBJECTID': 14312,
#   'USGS_Assigned_ID': 14312,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 2840.558722170961,
#   'GIS_Hectares': 1149.5333308021893,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3)',
#   'Listed_Fire_Codes': 'No code provided (3)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (2) | Listed Wildfire Controlled Date(s): 1963-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5351918762211072,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 16428.993576847337,
#   'Shape_Area': 11495333.308021892},
#  {'OBJECTID': 14313,
#   'USGS_Assigned_ID': 14313,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (2), 3 (3)',
#   'GIS_Acres': 2793.704800106442,
#   'GIS_Hectares': 1130.5722212600463,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (2), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_State_California_Wildfire_Polygons (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1)',
#   'Listed_Fire_Types': 'Wildfire (4), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'JESSE MORROW (5)',
#   'Listed_Fire_Codes': 'No code provided (5)',
#   'Listed_Fire_IDs': '0 (3)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-30 (2) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1), 1963-08-30 - DATE_CUR field (1)',
#   'Listed_Fire_Causes': '14 - Unknown / Unidentified (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (5)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': '',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5697200948078815,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 15791.497586562005,
#   'Shape_Area': 11305722.212600462},
#  {'OBJECTID': 14314,
#   'USGS_Assigned_ID': 14314,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (2), 3 (3)',
#   'GIS_Acres': 2683.2971883054856,
#   'GIS_Hectares': 1085.8918459701918,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (2), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_State_California_Wildfire_Polygons (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1)',
#   'Listed_Fire_Types': 'Wildfire (4), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'No Fire Name Provided (5)',
#   'Listed_Fire_Codes': 'No code provided (5)',
#   'Listed_Fire_IDs': '0 (3)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-14 (2) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1), 1963-08-14 - DATE_CUR field (1)',
#   'Listed_Fire_Causes': '14 - Unknown / Unidentified (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (5)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': '',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.3219743974345288,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 20586.738521923748,
#   'Shape_Area': 10858918.459701918},
#  {'OBJECTID': 14315,
#   'USGS_Assigned_ID': 14315,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 2585.2506290495035,
#   'GIS_Hectares': 1046.2138111682625,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (3)',
#   'Listed_Fire_Names': 'GROUSE (4)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-12-31 (3) | Listed Wildfire Controlled Date(s): 1963-12-31 (3)',
#   'Listed_Fire_Causes': 'Unknown (3)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (4)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.54328413499805,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 15556.132907498772,
#   'Shape_Area': 10462138.111682624},
#  {'OBJECTID': 14316,
#   'USGS_Assigned_ID': 14316,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 2532.860644395107,
#   'GIS_Hectares': 1025.0123365814543,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1), Comb_SubState_MNSRBOPNCA_Wildfires_Historic (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (3)',
#   'Listed_Fire_Names': 'JACKSON GULCH (4)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '1963-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-08-04 (3) | Listed Wildfire Controlled Date(s): 1963-12-31 (3)',
#   'Listed_Fire_Causes': 'Unknown (3)',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized-Topo (4)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5387467673975176,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 15462.408388868505,
#   'Shape_Area': 10250123.365814542},
#  {'OBJECTID': 14317,
#   'USGS_Assigned_ID': 14317,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1963,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (1)',
#   'GIS_Acres': 2144.285304565553,
#   'GIS_Hectares': 867.761475623905,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1)',
#   'Listed_Fire_Types': 'Wildfire (2)',
#   'Listed_Fire_Names': 'Lost Gulch (2)',
#   'Listed_Fire_Codes': 'No code provided (2)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1963-05-08 (1) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (2)',
#   'Listed_Rx_Reported_Acres': None,
# ...
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.3741557118084196,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 5971.641711825108,
#   'Shape_Area': 1061768.9022401064},
#  {'OBJECTID': 15293,
#   'USGS_Assigned_ID': 15293,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (2), 3 (3)',
#   'GIS_Acres': 261.7717596822939,
#   'GIS_Hectares': 105.93527268732407,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (2), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_State_California_Wildfire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (4), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'ELWORTHY (5)',
#   'Listed_Fire_Codes': 'No code provided (5)',
#   'Listed_Fire_IDs': '0 (3)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1966-06-28 (2) | Listed Other Fire Date(s): 1966-06-28 - DATE_CUR field (1), 1899-12-30 - REVDATE field (1)',
#   'Listed_Fire_Causes': '14 - Unknown / Unidentified (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (5)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': '',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.7240080229664898,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 4287.987760414402,
#   'Shape_Area': 1059352.7268732407},
#  {'OBJECTID': 15294,
#   'USGS_Assigned_ID': 15294,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 260.8262380093089,
#   'GIS_Hectares': 105.55263364184029,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Northern_Rockies_1889_2003 (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1)',
#   'Listed_Fire_Types': 'Wildfire (2), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'Owl Cr (3), No Fire Name Provided (1)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1966-08-05 (1) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (4)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Digitized Other (1)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.6444447180653424,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 4536.768665186041,
#   'Shape_Area': 1055526.3364184028},
#  {'OBJECTID': 15295,
#   'USGS_Assigned_ID': 15295,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (3)',
#   'GIS_Acres': 250.26472239441978,
#   'GIS_Hectares': 101.2785399122011,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_State_California_Wildfire_Polygons (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1)',
#   'Listed_Fire_Types': 'Wildfire (3), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'No Fire Name Provided (4)',
#   'Listed_Fire_Codes': 'No code provided (4)',
#   'Listed_Fire_IDs': '0 (3)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1)',
#   'Listed_Fire_Causes': '1 - Lightning (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3), Natural (1)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': '',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.5179576390777527,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 4956.972693836867,
#   'Shape_Area': 1012785.3991220109},
#  {'OBJECTID': 15296,
#   'USGS_Assigned_ID': 15296,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (2), 3 (3)',
#   'GIS_Acres': 238.76668744428318,
#   'GIS_Hectares': 96.62545025390709,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (2), Comb_National_USFS_Final_Fire_Perimeter (1), Comb_State_California_Wildfire_Polygons (1), Comb_National_WFDSS_Interagency_Fire_Perimeter_History (1)',
#   'Listed_Fire_Types': 'Wildfire (4), Likely Wildfire (1)',
#   'Listed_Fire_Names': 'VANDERBERG AFB #2 (5)',
#   'Listed_Fire_Codes': 'No code provided (5)',
#   'Listed_Fire_IDs': '0 (3)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1966-07-11 (2) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1), 1966-07-11 - DATE_CUR field (1)',
#   'Listed_Fire_Causes': '14 - Unknown / Unidentified (1)',
#   'Listed_Fire_Cause_Class': 'Undetermined (5)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': '',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.8347097558736323,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 3814.0198817521887,
#   'Shape_Area': 966254.5025390709},
#  {'OBJECTID': 15297,
#   'USGS_Assigned_ID': 15297,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (2)',
#   'GIS_Acres': 233.808017189495,
#   'GIS_Hectares': 94.61874759719176,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_BLM_Fire_Perimeters_LADP (1), Comb_SubState_BLM_Idaho_NOC_FPER_Historica_Fire_Polygons (1)',
#   'Listed_Fire_Types': 'Wildfire (1), Likely Wildfire (2)',
#   'Listed_Fire_Names': 'No Fire Name Provided (3)',
#   'Listed_Fire_Codes': 'No code provided (3)',
#   'Listed_Fire_IDs': '1966-NA-000000 (2)',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1966-12-31 (2) | Listed Wildfire Controlled Date(s): 1966-12-31 (2)',
#   'Listed_Fire_Causes': 'Unknown (2)',
#   'Listed_Fire_Cause_Class': 'Undetermined (3)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (3)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.27115353330182795,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 6621.949976584383,
#   'Shape_Area': 946187.4759719175},
#  {'OBJECTID': 15298,
#   'USGS_Assigned_ID': 15298,
#   'Assigned_Fire_Type': 'Wildfire',
#   'Fire_Year': 1966,
#   'Fire_Polygon_Tier': 1,
#   'Fire_Attribute_Tiers': '1 (1), 3 (1)',
#   'GIS_Acres': 232.41094718642483,
#   'GIS_Hectares': 94.05337342574508,
#   'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1), Comb_National_USFS_Final_Fire_Perimeter (1)',
#   'Listed_Fire_Types': 'Wildfire (2)',
#   'Listed_Fire_Names': 'Caudle Creek (2)',
#   'Listed_Fire_Codes': 'No code provided (2)',
#   'Listed_Fire_IDs': '',
#   'Listed_Fire_IRWIN_IDs': '',
#   'Listed_Fire_Dates': 'Listed Wildfire Discovery Date(s): 1966-08-17 (1) | Listed Other Fire Date(s): 1899-12-30 - REVDATE field (1)',
#   'Listed_Fire_Causes': '',
#   'Listed_Fire_Cause_Class': 'Undetermined (2)',
#   'Listed_Rx_Reported_Acres': None,
#   'Listed_Map_Digitize_Methods': 'Unknown (1)',
#   'Listed_Notes': '',
#   'Processing_Notes': '',
#   'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#   'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#   'Wildfire_and_Rx_Flag': None,
#   'Overlap_Within_1_or_2_Flag': None,
#   'Circleness_Scale': 0.7468705718421721,
#   'Circle_Flag': None,
#   'Exclude_From_Summary_Rasters': 'No',
#   'Shape_Length': 3978.042756657845,
#   'Shape_Area': 940533.7342574507},
#  ...]

# %%
filtered_fires_df = pd.DataFrame(filtered_fires)

# %%
filtered_fires_df.head()
# Out:
#    OBJECTID  USGS_Assigned_ID Assigned_Fire_Type  Fire_Year  \
# 0     14299             14299           Wildfire       1963
# 1     14300             14300           Wildfire       1963
# 2     14301             14301           Wildfire       1963
# 3     14302             14302           Wildfire       1963
# 4     14303             14303           Wildfire       1963
#
#    Fire_Polygon_Tier  Fire_Attribute_Tiers     GIS_Acres  GIS_Hectares  \
# 0                  1          1 (1), 3 (3)  40992.458271  16589.059302
# 1                  1          1 (1), 3 (3)  25757.090203  10423.524591
# 2                  1  1 (5), 3 (15), 5 (1)  45527.210986  18424.208617
# 3                  1   1 (1), 3 (3), 5 (1)  10395.010334   4206.711433
# 4                  1          1 (1), 3 (3)   9983.605738   4040.221900
#
#                                      Source_Datasets  \
# 0  Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 1  Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 2  Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 3  Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 4  Comb_National_NIFC_Interagency_Fire_Perimeter_...
#
#                     Listed_Fire_Types  ... Processing_Notes  \
# 0   Wildfire (1), Likely Wildfire (3)  ...
# 1   Wildfire (2), Likely Wildfire (2)  ...
# 2  Wildfire (6), Likely Wildfire (15)  ...
# 3   Wildfire (2), Likely Wildfire (3)  ...
# 4   Wildfire (1), Likely Wildfire (3)  ...
#
#                                      Wildfire_Notice  \
# 0  Wildfire mapping prior to 1984 was inconsisten...
# 1  Wildfire mapping prior to 1984 was inconsisten...
# 2  Wildfire mapping prior to 1984 was inconsisten...
# 3  Wildfire mapping prior to 1984 was inconsisten...
# 4  Wildfire mapping prior to 1984 was inconsisten...
#
#                               Prescribed_Burn_Notice Wildfire_and_Rx_Flag  \
# 0  Prescribed fire data in this dataset represent...                 None
# 1  Prescribed fire data in this dataset represent...                 None
# 2  Prescribed fire data in this dataset represent...                 None
# 3  Prescribed fire data in this dataset represent...                 None
# 4  Prescribed fire data in this dataset represent...                 None
#
#   Overlap_Within_1_or_2_Flag Circleness_Scale Circle_Flag  \
# 0                       None         0.385355         NaN
# 1                       None         0.364815         NaN
# 2                       None         0.320927         NaN
# 3                       None         0.428936         NaN
# 4                       None         0.703178         NaN
#
#   Exclude_From_Summary_Rasters  Shape_Length    Shape_Area
# 0                           No  73550.428118  1.658906e+08
# 1                           No  59920.576713  1.042352e+08
# 2                           No  84936.827810  1.842421e+08
# 3                           No  35105.903602  4.206711e+07
# 4                           No  26870.456126  4.040222e+07
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Join all the information

# %%
filtered_fires_df.to_csv('wildfire_attributes.csv', index=False)

# %% [markdown]
# In this notebook we focused on collecting al the relevant to the fildfire. In the upcoming notebooks we will manipulate the said data and come up with an smoke estimate.
